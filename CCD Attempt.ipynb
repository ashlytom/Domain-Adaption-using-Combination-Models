# %%
# !git clone https://github.com/kgl-prml/Contrastive-Adaptation-Network-for-Unsupervised-Domain-Adaptation.git
# Out:
# Cloning into 'Contrastive-Adaptation-Network-for-Unsupervised-Domain-Adaptation'...
# remote: Enumerating objects: 118, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 118 (delta 3), reused 14 (delta 2), pack-reused 99
# Receiving objects: 100% (118/118), 48.12 KiB | 2.41 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %%
cd /content/Contrastive-Adaptation-Network-for-Unsupervised-Domain-Adaptation
# Out:
# /content/Contrastive-Adaptation-Network-for-Unsupervised-Domain-Adaptation

# %%
# !python train.py
# Out:
# python3: can't open file 'train.py': [Errno 2] No such file or directory
