# %%
# !git clone https://github.com/NiXiao-cqu/TransferLearning-dwl-cvpr2021.git
# Out:
# Cloning into 'TransferLearning-dwl-cvpr2021'...
# remote: Enumerating objects: 72, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 72 (delta 14), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (72/72), done.

# %%
cd /content/TransferLearning-dwl-cvpr2021/TransferLearning-dwl-cvpr2021-master/dwl-cvpr2021/digital/classification
# Out:
# /content/TransferLearning-dwl-cvpr2021/TransferLearning-dwl-cvpr2021-master/dwl-cvpr2021/digital/classification

# %%
pip install POT
# Out:
# ...
#      |████████████████████████████████| 430 kB 3.6 MB/s
# ...

# %%
# !wget http://ufldl.stanford.edu/housenumbers/train_32x32.mat
# !wget http://ufldl.stanford.edu/housenumbers/test_32x32.mat
# Out:
# --2021-10-19 06:12:15--  http://ufldl.stanford.edu/housenumbers/train_32x32.mat
# Resolving ufldl.stanford.edu (ufldl.stanford.edu)... 171.64.68.10
# Connecting to ufldl.stanford.edu (ufldl.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 182040794 (174M) [text/plain]
# Saving to: ‘train_32x32.mat’
#
# train_32x32.mat     100%[===================>] 173.61M  20.1MB/s    in 11s
#
# 2021-10-19 06:12:26 (16.5 MB/s) - ‘train_32x32.mat’ saved [182040794/182040794]
#
# --2021-10-19 06:12:26--  http://ufldl.stanford.edu/housenumbers/test_32x32.mat
# Resolving ufldl.stanford.edu (ufldl.stanford.edu)... 171.64.68.10
# Connecting to ufldl.stanford.edu (ufldl.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64275384 (61M) [text/plain]
# Saving to: ‘test_32x32.mat’
#
# test_32x32.mat      100%[===================>]  61.30M  16.1MB/s    in 4.3s
#
# ...

# %%
mkdir "/content/TransferLearning-dwl-cvpr2021/TransferLearning-dwl-cvpr2021-master/dwl-cvpr2021/digital/classification/data/svhn"

# %%
# !mv "/content/TransferLearning-dwl-cvpr2021/TransferLearning-dwl-cvpr2021-master/dwl-cvpr2021/digital/classification/train_32x32.mat" "/content/TransferLearning-dwl-cvpr2021/TransferLearning-dwl-cvpr2021-master/dwl-cvpr2021/digital/classification/data/svhn"
# !mv "/content/TransferLearning-dwl-cvpr2021/TransferLearning-dwl-cvpr2021-master/dwl-cvpr2021/digital/classification/test_32x32.mat" "/content/TransferLearning-dwl-cvpr2021/TransferLearning-dwl-cvpr2021-master/dwl-cvpr2021/digital/classification/data/svhn"

# %%
#Downloading MNIST-M.mat file Link: https://drive.google.com/file/d/1cZ4vSIS-IKoyKWPfcgxFMugw0LtMiqPf/view
from google_drive_downloader import GoogleDriveDownloader as gdd

gdd.download_file_from_google_drive(file_id='1cZ4vSIS-IKoyKWPfcgxFMugw0LtMiqPf',
                                    dest_path='/content/TransferLearning-dwl-cvpr2021/TransferLearning-dwl-cvpr2021-master/dwl-cvpr2021/digital/classification/data/mnist_data.mat',
                                    unzip=False)

# %%
import torch

# %%
 torch. __version__
# Out:
# '1.9.0+cu111'

# %%
#Need Earlier version 0.3.0 or somethign to work properly

# %%
#within Solver.py before running main.py
#Line 121 and 126 change the softmax
""""def ent(self, output):
        out = -torch.mean(F.softmax(output.cuda() + 1e-6,-1)*torch.log(F.softmax(output.cuda() + 1e-6,-1)))   Line 121
        out = Variable(out,requires_grad=True)
        return out

    def discrepancy(self, out1, out2):
        return torch.mean(torch.abs(F.softmax(out1,-1) - F.softmax(out2,-1)))                                  Line 126 
         """"   

"""Line 310,316,41,43,45 - replace self.scale with self.Resize 
     

Line 421 - 
     with torch.no_grad(): 
        img, label = Variable(img), Variable(label) """
# Out:
#   File "<ipython-input-25-1f85a93d321a>", line 10
#     """"
#
# ^
# SyntaxError: EOL while scanning string literal

# %%
# one can use the parser arguments as given in the main.py file to change
# different components of the model
#i think it works like
# !python main.py --all use --batch-size --eval_only etc : For more refer the main.py file,
# could be used to save the epochs and run them separately

# %%
#import ot
# !python main.py
# Out:
# Namespace(all_use='no', batch_size=128, checkpoint_dir='checkpoint', cuda=True, eval_only=False, gpu_id='0', lr=0.0002, max_epoch=200, no_cuda=False, num_k=4, one_step=False, optimizer='adam', resume_epoch=100, save_epoch=10, save_model=False, seed=1, source='svhn', target='mnist', use_abs_diff=False)
# dataset loading
# (55000, 3, 32, 32)
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:279: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   warnings.warn("The use of the transforms.Scale transform is deprecated, " +
# load finished!
# /content/TransferLearning-dwl-cvpr2021/TransferLearning-dwl-cvpr2021-master/dwl-cvpr2021/digital/classification/solver.py:126: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return torch.mean(torch.abs(F.softmax(out1) - F.softmax(out2)))
# ...

# %% [markdown]
# Issue: 35 mins for 1 epoch  \\
# In Collab Pro: 30 min for 3 epochs
