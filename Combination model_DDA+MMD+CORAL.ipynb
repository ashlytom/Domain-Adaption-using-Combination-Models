# %%
# !git clone https://github.com/swag-kaust/dda_pytorch.git
# Out:
# Cloning into 'dda_pytorch'...
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 66 (delta 27), reused 51 (delta 15), pack-reused 0
# Unpacking objects: 100% (66/66), done.

# %%
cd /content/dda_pytorch
# Out:
# /content/dda_pytorch

# %%
import os
import sys
import tqdm
import random
import numpy as np
#Fouerir tranform??
from numpy.fft import rfft2, irfft2, fftshift, ifftshift

import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.nn as nn
import torch.utils.data
from torchvision import datasets
from torchvision import transforms

from components.data_loader import GetLoader
from components.model import CNNModel
from components.test import test
import components.shared as sd

# %%
# Paths to datasets
source_dataset_name = 'MNIST'
target_dataset_name = 'mnist_m'
source_image_root = os.path.join('dataset', source_dataset_name)
target_image_root = os.path.join('dataset', target_dataset_name)
os.makedirs('./dataset', exist_ok=True)

# Where to save outputs
model_root = './out_ex3_cnn_da'
os.makedirs(model_root, exist_ok=True)

# %%
cuda = True
cudnn.benchmark = True

# Hyperparameters
lr = 1e-3
batch_size = 128
image_size = 28
n_epoch = 100

# manual_seed = random.randint(1, 10000)
manual_seed = 222
random.seed(manual_seed)
torch.manual_seed(manual_seed)
print(f'Random seed: {manual_seed}')
# Out:
# Random seed: 222

# %% [markdown]
# ### The download method has changed since the previous code,so i need to use this method for the earlier verisons of the code.

# %%
import tarfile
my_tar = tarfile.open('/content/drive/MyDrive/Colab Notebooks/Thesis Domain adaptation/Datasets/mnist_m (1).tar')
my_tar.extractall('/content/dda_pytorch/dataset') # specify which folder to extract to
my_tar.close()

# %%
# Transformations / augmentations
img_transform_source = transforms.Compose([
    transforms.Resize(image_size),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.1307,), std=(0.3081,)),
    transforms.Lambda(lambda x: x.repeat(3, 1, 1)),
])

img_transform_target = transforms.Compose([
    transforms.Resize(image_size),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
])

# Load MNIST dataset
dataset_source = datasets.MNIST(
    root='dataset',
    train=True,
    transform=img_transform_source,
    download=True
)

# Load MNIST-M dataset
train_list = os.path.join(target_image_root, 'mnist_m_train_labels.txt')
dataset_target = GetLoader(
    data_root=os.path.join(target_image_root, 'mnist_m_train'),
    data_list=train_list,
    transform=img_transform_target
)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to dataset/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting dataset/MNIST/raw/train-images-idx3-ubyte.gz to dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to dataset/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting dataset/MNIST/raw/train-labels-idx1-ubyte.gz to dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to dataset/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting dataset/MNIST/raw/t10k-images-idx3-ubyte.gz to dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz to dataset/MNIST/raw

# %%
def get_global_acorr_for_loader(loader):
    """ The average auto-correlation of all images in the dataset """
    global_acorr = np.zeros((3, 28, 15), dtype=np.complex128)
    prog_bar = tqdm.tqdm(loader)
    for data, _ in prog_bar:
        data_f = np.fft.rfft2(data, s=data.shape[-2:], axes=(-2, -1))
        # Auto-correlation is multiplication with the conjucate of self
        # in frequency domain
        global_acorr += data_f * np.conjugate(data_f)
    global_acorr /= len(loader)
    print(global_acorr.shape)
    return np.fft.fftshift(global_acorr)

def route_to(fname):
    """ Shortcut for routing to the save folder """
    return os.path.join(model_root, fname)

# Compute global acorr if not in the folder, load otherwise
if not 'gacorr_dst_tr.npy' in os.listdir(model_root):
    print('Save global acorr')
    gacorr_dst_tr = get_global_acorr_for_loader(dataset_target)
    gacorr_src_tr = get_global_acorr_for_loader(dataset_source)
    np.save(route_to('gacorr_dst_tr.npy'), gacorr_dst_tr)
    np.save(route_to('gacorr_src_tr.npy'), gacorr_src_tr)
else:
    print('Load global acorr')
    gacorr_dst_tr = np.load(route_to('gacorr_dst_tr.npy'))
    gacorr_src_tr = np.load(route_to('gacorr_src_tr.npy'))
# Out:
# Save global acorr
# 100%|██████████| 59001/59001 [00:33<00:00, 1775.76it/s]
# (3, 28, 15)
# 100%|██████████| 60000/60000 [00:17<00:00, 3431.76it/s]
# (3, 28, 15)

# %%
# Window size
crop_size = 1
print(f'Use the crop size for xcorr = {crop_size}')
# Out:
# Use the crop size for xcorr = 1

# %%
def crop_ref(x, n=1, edge=5):
    """Crop a window from the image
    Args:
        x(np.ndarray): image [c, h, w]
        n(int): window size
        edge(int): margin to avoid from edges of the image
    """
    if n % 2 == 0: n+=1;
    k = int((n - 1) / 2)
    nz, nx = x.shape[-2:]
    dim1 = np.random.randint(0+k+edge, nz-k-edge)
    dim2 = np.random.randint(0+k, nx-k)
    out = x[..., dim1-k:dim1+k+1, dim2-k:dim2+k+1]
    return out

# crop_ref(np.ones((2, 100, 100)), n=5).shape

# %%
def get_global_xcorr_for_loader(loader, crop_size=1):
    # Init the placeholder for average
    rand_pixel = np.zeros((3, crop_size, crop_size))
    
    # Loop over all images in the dataset
    prog_bar = tqdm.tqdm(loader)
    for data, _ in prog_bar:
        rand_pixel += np.mean(crop_ref(data, crop_size).numpy(), axis=0)
    rand_pixel /= len(loader)
    
    # Place the mean pixel into center of an empty image
    c, h ,w = data.shape
    mid_h, mid_w = int(h // 2), int(w // 2)
    embed = np.zeros_like(data)
    embed[..., mid_h:mid_h+1, mid_w:mid_w+1] = rand_pixel
    global_xcorr = np.fft.rfft2(embed, s=data.shape[-2:], axes=(-2, -1))
    return np.fft.fftshift(global_xcorr)


# Compute global xcorr if not in the folder, load otherwise
if not 'gxcorr_dst_tr.npy' in os.listdir(model_root):
# if True:
    print('Save global xcorr')
    gxcorr_dst_tr = get_global_xcorr_for_loader(dataset_target, crop_size)
    gxcorr_src_tr = get_global_xcorr_for_loader(dataset_source, crop_size)
    np.save(route_to('gxcorr_dst_tr.npy'), gxcorr_dst_tr)
    np.save(route_to('gxcorr_src_tr.npy'), gxcorr_src_tr)
else:
    print('Load global xcorr')
    gxcorr_dst_tr = np.load(route_to('gxcorr_dst_tr.npy'))
    gxcorr_src_tr = np.load(route_to('gxcorr_src_tr.npy'))
# Out:
# Save global xcorr
# 100%|██████████| 59001/59001 [00:30<00:00, 1906.62it/s]
# 100%|██████████| 60000/60000 [00:15<00:00, 3819.09it/s]

# %%
def flip_channels(x):
    """Reverse polarity of random channels"""
    flip_matrix = np.random.choice([-1, 1], 3)[..., np.newaxis, np.newaxis] 
    return (x * flip_matrix).astype(np.float32)

def shuffle_channels(x):
    """Change order of channels"""
    return np.random.permutation(x)

def normalize_channels(x):
    """Map data to [-1,1] range. The scaling after conv(xcorr, acorr) is not 
    suitable for image processing so this function fixes it"""
    cmin = np.min(x, axis=(-2,-1))[..., np.newaxis, np.newaxis]
    x -= cmin
    cmax = np.max(np.abs(x), axis=(-2,-1))[..., np.newaxis, np.newaxis]
    x /= cmax
    x *= 2
    x -= 1
    return x.astype(np.float32)

# %%
class DDALoaderTrain(torch.utils.data.Dataset):
    def __init__(self, loader1, avg_acorr2, p=0.5, crop_size=1):
        super().__init__()
        self.loader1 = loader1
        self.avg_acorr2 = avg_acorr2
        self.p = p
        self.crop_size = crop_size
        
    def __len__(self):
        return len(self.loader1)
        
    def __getitem__(self, item):
        # Get main data (data, label)
        data, label = self.loader1.__getitem__(item)
        data_fft = fftshift(rfft2(data, s=data.shape[-2:], axes=(-2, -1)))
        
        # Get random pixel from another data from the same dataset
        random_index = np.random.randint(0, len(self.loader1))
        another_data, _ = self.loader1.__getitem__(random_index)
        rand_pixel = crop_ref(another_data, self.crop_size)
        
        # Convert to Fourier domain
        c, h ,w = another_data.shape
        mid_h, mid_w = int(h // 2), int(w // 2)
        embed = np.zeros_like(another_data)
        embed[:, mid_h:mid_h+1, mid_w:mid_w+1] = rand_pixel
        pixel_fft = np.fft.rfft2(embed, s=another_data.shape[-2:], axes=(-2, -1))
        pixel_fft = np.fft.fftshift(pixel_fft)
            
        # Cross-correlate the data sample with the random pixel from the same dataset
        xcorr = data_fft * np.conjugate(pixel_fft)

        # Convolve the ruslt with the auto-correlation of another dataset
        conv = xcorr * self.avg_acorr2

        # Reverse Fourier domain and map channels to [-1, 1] range
        data_da = fftshift(irfft2(ifftshift(conv), axes=(-2, -1)))
        data_da = normalize_channels(data_da)
        
        # Apply data augmentations
        if np.random.rand() < self.p:
            data_da = flip_channels(data_da)
        if np.random.rand() < self.p:
            data_da = shuffle_channels(data_da)
            
        # Return a pair of data / label
        return data_da.astype(np.float32), label

# %%
dataset_source = DDALoaderTrain(dataset_source, gacorr_dst_tr)
dataset_target = DDALoaderTrain(dataset_target, gacorr_src_tr)

dummy_data, dummy_label = dataset_source.__getitem__(0)
print('Image shape: {}\t Label: {}'.format(dummy_data.shape, dummy_label))
# Out:
# Image shape: (3, 28, 28)	 Label: 5

# %%
class DDALoaderTest(torch.utils.data.Dataset):
    def __init__(self, loader1, avg_acorr2, avg_xcorr1):
        super().__init__()
        self.loader1 = loader1
        self.avg_acorr2 = avg_acorr2
        self.avg_xcorr1 = avg_xcorr1
        
    def __len__(self):
        return len(self.loader1)
        
    def __getitem__(self, item):
        data, label = self.loader1.__getitem__(item)
        data_fft = fftshift(rfft2(data, s=data.shape[-2:], axes=(-2, -1)))
        
        xcorr = data_fft * np.conjugate(self.avg_xcorr1)
        conv = xcorr * self.avg_acorr2

        data_da = fftshift(irfft2(ifftshift(conv), axes=(-2, -1)))
        data_da = normalize_channels(data_da)
        return data_da.astype(np.float32), label

# %%
def test(dataset_name, model_root, crop_size=1):
    image_root = os.path.join('dataset', dataset_name)  
    if dataset_name == 'mnist_m':
        test_list = os.path.join(image_root, 'mnist_m_test_labels.txt')
        dataset = GetLoader(
            data_root=os.path.join(image_root, 'mnist_m_test'),
            data_list=test_list,
            transform=img_transform_target
        )
        
        if not 'gxcorr_dst_te.npy' in os.listdir(model_root):
            print('Save global acorr and xcorr')
            # acorr
            gacorr_src_te = get_global_acorr_for_loader(dataset)
            np.save(route_to('gacorr_src_te.npy'), gacorr_src_te)
            # xcorr
            gxcorr_dst_te = get_global_xcorr_for_loader(dataset, crop_size)
            np.save(route_to('gxcorr_dst_te.npy'), gxcorr_dst_te)
        else:
            gacorr_src_te = np.load(route_to('gacorr_src_te.npy'))
            gxcorr_dst_te = np.load(route_to('gxcorr_dst_te.npy'))
            
        # Init loader for MNIST-M
        dataset = DDALoaderTest(dataset, gacorr_src_te, gxcorr_dst_te)
    else:
        dataset = datasets.MNIST(
            root='dataset',
            train=False,
            transform=img_transform_source,
        )
        if not 'gxcorr_src_te.npy' in os.listdir(model_root):
            print('Save global acorr and xcorr')
            # acorr
            gacorr_dst_te = get_global_acorr_for_loader(dataset)
            np.save(route_to('gacorr_dst_te.npy'), gacorr_dst_te)
            # xcorr
            gxcorr_src_te = get_global_xcorr_for_loader(dataset, crop_size)
            np.save(route_to('gxcorr_src_te.npy'), gxcorr_src_te)
        else:
            gacorr_dst_te = np.load(route_to('gacorr_dst_te.npy'))
            gxcorr_src_te = np.load(route_to('gxcorr_src_te.npy'))
            
        # Init loader for MNIST
        dataset = DDALoaderTest(dataset, gacorr_dst_te, gxcorr_src_te)

    dataloader = torch.utils.data.DataLoader(
        dataset=dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=8
    )

    """ test """
    my_net = torch.load(os.path.join(model_root, 'mnist_mnistm_model_epoch_current.pth'))
    my_net = my_net.eval()

    if cuda:
        my_net = my_net.cuda()

    len_dataloader = len(dataloader)
    data_target_iter = iter(dataloader)

    i = 0
    n_total = 0
    n_correct = 0

    while i < len_dataloader:
        # test model using target data
        data_target = data_target_iter.next()
        t_img, t_label = data_target

        _batch_size = len(t_label)

        if cuda:
            t_img = t_img.cuda()
            t_label = t_label.cuda()

        class_output, _ , _, _= my_net(input_data=t_img, alpha=0)
        pred = class_output.data.max(1, keepdim=True)[1]
        n_correct += pred.eq(t_label.data.view_as(pred)).cpu().sum()
        n_total += _batch_size
        i += 1

    accu = n_correct.data.numpy() * 1.0 / n_total
    return accu

# %%
dataloader_source = torch.utils.data.DataLoader(
    dataset=dataset_source,
    batch_size=batch_size,
    shuffle=True,
    num_workers=8)

dataloader_target = torch.utils.data.DataLoader(
    dataset=dataset_target,
    batch_size=batch_size,
    shuffle=True,
    num_workers=8)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        self.feature = nn.Sequential()
        self.feature.add_module('f_conv1', nn.Conv2d(3, 64, kernel_size=5))
        self.feature.add_module('f_bn1', nn.BatchNorm2d(64))
        self.feature.add_module('f_pool1', nn.MaxPool2d(2))
        self.feature.add_module('f_relu1', nn.ReLU(True))
        self.feature.add_module('f_conv2', nn.Conv2d(64, 50, kernel_size=5))
        self.feature.add_module('f_bn2', nn.BatchNorm2d(50))
        self.feature.add_module('f_drop1', nn.Dropout2d())
        self.feature.add_module('f_pool2', nn.MaxPool2d(2))
        self.feature.add_module('f_relu2', nn.ReLU(True))

        self.class_classifier = nn.Sequential()
        self.class_classifier.add_module('c_fc1', nn.Linear(50 * 4 * 4, 3000))
        self.class_classifier.add_module('c_bn1', nn.BatchNorm1d(3000))
        self.class_classifier.add_module('c_relu1', nn.ReLU(True))
        self.class_classifier.add_module('c_drop1', nn.Dropout())

        self.extraction = nn.Sequential()
        self.extraction.add_module('c_fc2', nn.Linear(3000, 5000))
        self.extraction.add_module('c_bn2', nn.BatchNorm1d(5000))
        self.extraction.add_module('c_relu2', nn.ReLU(True))

        self.newloss = nn.Sequential()
        self.newloss.add_module('c_fc2', nn.Linear(5000, 200))
        self.newloss.add_module('c_bn2', nn.BatchNorm1d(200))
        self.newloss.add_module('c_relu2', nn.ReLU(True))

        self.original_class = nn.Sequential()
        self.original_class.add_module('c_fc3', nn.Linear(200, 10))
        self.original_class.add_module('c_softmax', nn.LogSoftmax(dim=1))

    def forward(self, input_data, alpha):
        input_data = input_data.expand(input_data.data.shape[0], 3, 28, 28)
        feature = self.feature(input_data)
        feature = feature.view(-1, 50 * 4 * 4)
        inter_1 = self.class_classifier(feature)
        inter_2 = self.extraction(inter_1)
        inter_3 = self.newloss(inter_2)
        class_output = self.original_class(inter_3)

        return class_output, 0, inter_2, inter_3

# %%
def CORAL(source, target):
    d = source.size(1)
    ns, nt = source.size(0), target.size(0)

    # source covariance
    tmp_s = torch.ones((1, ns)).cuda() @ source
    cs = (source.t() @ source - (tmp_s.t() @ tmp_s) / ns) / (ns - 1)

    # target covariance
    tmp_t = torch.ones((1, nt)).cuda() @ target
    ct = (target.t() @ target - (tmp_t.t() @ tmp_t) / nt) / (nt - 1)

    # frobenius norm
    loss = (cs - ct).pow(2).sum().sqrt()
    loss = loss / (4 * d * d)

    return loss

# %%
class MMD_loss(nn.Module):    #nn.Module inheriting the .module into the class.
    def __init__(self, kernel_type='rbf', kernel_mul=2.0, kernel_num=5):
        super(MMD_loss, self).__init__()
        self.kernel_num = kernel_num
        self.kernel_mul = kernel_mul
        self.fix_sigma = None
        self.kernel_type = kernel_type

    def guassian_kernel(self, source, target, kernel_mul=2.0, kernel_num=5, fix_sigma=None):
        n_samples = int(source.size()[0]) + int(target.size()[0])
        total = torch.cat([source, target], dim=0)
        total0 = total.unsqueeze(0).expand(
            int(total.size(0)), int(total.size(0)), int(total.size(1)))
        total1 = total.unsqueeze(1).expand(
            int(total.size(0)), int(total.size(0)), int(total.size(1)))
        L2_distance = ((total0-total1)**2).sum(2)
        if fix_sigma:
            bandwidth = fix_sigma
        else:
            bandwidth = torch.sum(L2_distance.data) / (n_samples**2-n_samples)
        bandwidth /= kernel_mul ** (kernel_num // 2)
        bandwidth_list = [bandwidth * (kernel_mul**i)
                          for i in range(kernel_num)]
        kernel_val = [torch.exp(-L2_distance / bandwidth_temp)
                      for bandwidth_temp in bandwidth_list]
        return sum(kernel_val)

    def linear_mmd2(self, f_of_X, f_of_Y):
        loss = 0.0
        delta = f_of_X.float().mean(0) - f_of_Y.float().mean(0)
        loss = delta.dot(delta.T)
        return loss

    def forward(self, source, target):
        if self.kernel_type == 'linear':
            return self.linear_mmd2(source, target)
        elif self.kernel_type == 'rbf':
            batch_size = int(source.size()[0])
            kernels = self.guassian_kernel(
                source, target, kernel_mul=self.kernel_mul, kernel_num=self.kernel_num, fix_sigma=self.fix_sigma)
            XX = torch.mean(kernels[:batch_size, :batch_size])
            YY = torch.mean(kernels[batch_size:, batch_size:])
            XY = torch.mean(kernels[:batch_size, batch_size:])
            YX = torch.mean(kernels[batch_size:, :batch_size])
            loss = torch.mean(XX + YY - XY - YX)
            return loss

# %%
# load model
my_net = CNNModel()

# setup optimizer
optimizer = optim.Adam(my_net.parameters(), lr=lr)

loss_class = torch.nn.NLLLoss()

if cuda:
    my_net = my_net.cuda()
    loss_class = loss_class.cuda()

for p in my_net.parameters():
    p.requires_grad = True

# %%
# Record losses for each epoch (used in compare.ipynb)
losses = {'test': {'acc_bw': [], 'acc_color': []}}
name_losses = 'losses.pkl'
lamba_c = 10000000
lamba_m = 10

# %%
early_stop = 20

# %%
if not name_losses in os.listdir(model_root):
    stop = 0
# if True:
    # training
    best_accu_t = 0.0
    for epoch in range(n_epoch):
        stop += 1

        len_dataloader = min(len(dataloader_source), len(dataloader_target))
        data_source_iter = iter(dataloader_source)
        data_target_iter = iter(dataloader_target)

        for i in range(len_dataloader):

            p = float(i + epoch * len_dataloader) / n_epoch / len_dataloader
            alpha = 2. / (1. + np.exp(-10 * p)) - 1

            # training model using source data
            data_source = data_source_iter.next()
            s_img, s_label = data_source

            # for target data
            data_target = data_target_iter.next()
            t_img, _ = data_target

            my_net.zero_grad()
            batch_size = len(s_label)

            if cuda:
                s_img = s_img.cuda()
                s_label = s_label.cuda()
                t_img = t_img.cuda()

            class_output, _ , src1, src2 = my_net(input_data=s_img, alpha=alpha)
            _, _ , trg1,trg2 = my_net(input_data=t_img, alpha=alpha)

            #CORAL Loss
            
            coral_loss1 = CORAL(src1 , trg1)
            
            coral1 = lamba_c*coral_loss1
            
            actual_coral = coral1 

            #MMD Loss
            mmd_loss = MMD_loss()
            mmd_loss_var = mmd_loss(src2 , trg2)
            actual_mmd = lamba_m*mmd_loss_var

            #Network loss
            network_loss = loss_class(class_output, s_label)

            #Combination            
            err_s_label = network_loss + actual_coral + actual_mmd

            

            err = err_s_label
            err.backward()
            optimizer.step()

            sys.stdout.write('\r epoch: %d, [iter: %d / all %d], Total Loss: %f, Network_loss:%f, CORAL_loss_actual: %f , MMD_loss_actual : %f ' \
                  % (epoch, i + 1, len_dataloader, err_s_label.data.cpu().numpy(), network_loss.data.cpu().numpy() ,actual_coral.data.cpu().numpy(), actual_mmd.data.cpu().numpy()))
            sys.stdout.flush()
            torch.save(my_net, '{0}/mnist_mnistm_model_epoch_current.pth'.format(model_root))

        print('\n')
        accu_s = test(source_dataset_name, model_root)
        print('Accuracy of the %s dataset: %f' % ('mnist', accu_s))
        accu_t = test(target_dataset_name, model_root)
        print('Accuracy of the %s dataset: %f\n' % ('mnist_m', accu_t))

        losses['test']['acc_bw'].append(accu_s)
        losses['test']['acc_color'].append(accu_t)

        if accu_t > best_accu_t:
            best_accu_s = accu_s
            best_accu_t = accu_t
            torch.save(my_net, '{0}/mnist_mnistm_model_epoch_best.pth'.format(model_root))
            stop = 0
        if stop >= early_stop:
          break

    print('============ Summary ============= \n')
    print('Accuracy of the %s dataset: %f' % ('mnist', best_accu_s))
    print('Accuracy of the %s dataset: %f' % ('mnist_m', best_accu_t))
    print('Corresponding model was save in ' + model_root + '/mnist_mnistm_model_epoch_best.pth')
    sd.save_dict(os.path.join(model_root, 'losses.pkl'), losses)
else:
    path_losses = os.path.join(model_root, name_losses)
    print(f'Losses from previous run found!')
    losses = sd.load_dict(path_losses)
    sd.plot_curves(losses)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#  epoch: 0, [iter: 461 / all 461], Total Loss: 2.256495, Network_loss:1.716150, CORAL_loss_actual: 0.327423 , MMD_loss_actual : 0.212922
#
# Save global acorr and xcorr
# 100%|██████████| 10000/10000 [00:03<00:00, 3213.97it/s]
# (3, 28, 15)
# 100%|██████████| 10000/10000 [00:02<00:00, 3622.44it/s]
# Accuracy of the mnist dataset: 0.249200
# Save global acorr and xcorr
# 100%|██████████| 9001/9001 [00:08<00:00, 1030.50it/s]
# (3, 28, 15)
# 100%|██████████| 9001/9001 [00:04<00:00, 1841.49it/s]
# Accuracy of the mnist_m dataset: 0.258860
#
#  epoch: 1, [iter: 461 / all 461], Total Loss: 1.296662, Network_loss:0.887624, CORAL_loss_actual: 0.109880 , MMD_loss_actual : 0.299158
#
# Accuracy of the mnist dataset: 0.569000
# Accuracy of the mnist_m dataset: 0.373847
#
#  epoch: 2, [iter: 461 / all 461], Total Loss: 1.122295, Network_loss:0.775080, CORAL_loss_actual: 0.039813 , MMD_loss_actual : 0.307403
#
# Accuracy of the mnist dataset: 0.689600
# Accuracy of the mnist_m dataset: 0.438618
#
#  epoch: 3, [iter: 461 / all 461], Total Loss: 0.704194, Network_loss:0.478851, CORAL_loss_actual: 0.030297 , MMD_loss_actual : 0.195045
#
# Accuracy of the mnist dataset: 0.784400
# Accuracy of the mnist_m dataset: 0.489834
#
#  epoch: 4, [iter: 461 / all 461], Total Loss: 0.840718, Network_loss:0.492472, CORAL_loss_actual: 0.042736 , MMD_loss_actual : 0.305510
#
# Accuracy of the mnist dataset: 0.842300
# Accuracy of the mnist_m dataset: 0.521720
#
#  epoch: 5, [iter: 461 / all 461], Total Loss: 0.767623, Network_loss:0.448417, CORAL_loss_actual: 0.033934 , MMD_loss_actual : 0.285273
#
# Accuracy of the mnist dataset: 0.891500
# Accuracy of the mnist_m dataset: 0.548828
#
#  epoch: 6, [iter: 461 / all 461], Total Loss: 0.660090, Network_loss:0.351593, CORAL_loss_actual: 0.018318 , MMD_loss_actual : 0.290179
#
# Accuracy of the mnist dataset: 0.903700
# Accuracy of the mnist_m dataset: 0.554383
#
#  epoch: 7, [iter: 461 / all 461], Total Loss: 0.738429, Network_loss:0.416924, CORAL_loss_actual: 0.020254 , MMD_loss_actual : 0.301251
#
# Accuracy of the mnist dataset: 0.921600
# Accuracy of the mnist_m dataset: 0.568270
#
#  epoch: 8, [iter: 461 / all 461], Total Loss: 0.659009, Network_loss:0.362134, CORAL_loss_actual: 0.016413 , MMD_loss_actual : 0.280461
#
# Accuracy of the mnist dataset: 0.930900
# Accuracy of the mnist_m dataset: 0.586490
#
#  epoch: 9, [iter: 461 / all 461], Total Loss: 0.595941, Network_loss:0.340125, CORAL_loss_actual: 0.017921 , MMD_loss_actual : 0.237894
#
# Accuracy of the mnist dataset: 0.924200
# Accuracy of the mnist_m dataset: 0.589490
#
#  epoch: 10, [iter: 461 / all 461], Total Loss: 0.593903, Network_loss:0.346093, CORAL_loss_actual: 0.014288 , MMD_loss_actual : 0.233521
#
# Accuracy of the mnist dataset: 0.938100
# Accuracy of the mnist_m dataset: 0.612154
#
#  epoch: 11, [iter: 461 / all 461], Total Loss: 0.554230, Network_loss:0.373389, CORAL_loss_actual: 0.011053 , MMD_loss_actual : 0.169787
#
# Accuracy of the mnist dataset: 0.951600
# Accuracy of the mnist_m dataset: 0.634152
#
#  epoch: 12, [iter: 461 / all 461], Total Loss: 0.570054, Network_loss:0.354061, CORAL_loss_actual: 0.011835 , MMD_loss_actual : 0.204158
#
# Accuracy of the mnist dataset: 0.946400
# Accuracy of the mnist_m dataset: 0.635041
#
#  epoch: 13, [iter: 461 / all 461], Total Loss: 0.610515, Network_loss:0.327243, CORAL_loss_actual: 0.010107 , MMD_loss_actual : 0.273166
#
# Accuracy of the mnist dataset: 0.950100
# Accuracy of the mnist_m dataset: 0.643373
#
#  epoch: 14, [iter: 461 / all 461], Total Loss: 0.565976, Network_loss:0.231657, CORAL_loss_actual: 0.009846 , MMD_loss_actual : 0.324473
#
# Accuracy of the mnist dataset: 0.950500
# Accuracy of the mnist_m dataset: 0.658816
#
#  epoch: 15, [iter: 461 / all 461], Total Loss: 0.448328, Network_loss:0.261149, CORAL_loss_actual: 0.010005 , MMD_loss_actual : 0.177174
#
# Accuracy of the mnist dataset: 0.953000
# Accuracy of the mnist_m dataset: 0.637151
#
#  epoch: 16, [iter: 461 / all 461], Total Loss: 0.423992, Network_loss:0.211107, CORAL_loss_actual: 0.007926 , MMD_loss_actual : 0.204959
#
# Accuracy of the mnist dataset: 0.955400
# Accuracy of the mnist_m dataset: 0.653150
#
#  epoch: 17, [iter: 461 / all 461], Total Loss: 0.431620, Network_loss:0.233429, CORAL_loss_actual: 0.012587 , MMD_loss_actual : 0.185604
#
# Accuracy of the mnist dataset: 0.958100
# Accuracy of the mnist_m dataset: 0.672925
#
#  epoch: 18, [iter: 461 / all 461], Total Loss: 0.483711, Network_loss:0.262831, CORAL_loss_actual: 0.009198 , MMD_loss_actual : 0.211682
#
# Accuracy of the mnist dataset: 0.957700
# Accuracy of the mnist_m dataset: 0.673592
#
#  epoch: 19, [iter: 461 / all 461], Total Loss: 0.496626, Network_loss:0.272869, CORAL_loss_actual: 0.009976 , MMD_loss_actual : 0.213780
#
# Accuracy of the mnist dataset: 0.960700
# Accuracy of the mnist_m dataset: 0.687368
#
#  epoch: 20, [iter: 461 / all 461], Total Loss: 0.473119, Network_loss:0.243214, CORAL_loss_actual: 0.008176 , MMD_loss_actual : 0.221729
#
# Accuracy of the mnist dataset: 0.971700
# Accuracy of the mnist_m dataset: 0.676814
#
#  epoch: 21, [iter: 461 / all 461], Total Loss: 0.517913, Network_loss:0.287573, CORAL_loss_actual: 0.007046 , MMD_loss_actual : 0.223293
#
# Accuracy of the mnist dataset: 0.965300
# Accuracy of the mnist_m dataset: 0.689257
#
#  epoch: 22, [iter: 461 / all 461], Total Loss: 0.432695, Network_loss:0.262903, CORAL_loss_actual: 0.008202 , MMD_loss_actual : 0.161591
#
# Accuracy of the mnist dataset: 0.966100
# Accuracy of the mnist_m dataset: 0.700811
#
#  epoch: 23, [iter: 461 / all 461], Total Loss: 0.406110, Network_loss:0.183557, CORAL_loss_actual: 0.014735 , MMD_loss_actual : 0.207818
#
# Accuracy of the mnist dataset: 0.971000
# Accuracy of the mnist_m dataset: 0.693812
#
#  epoch: 24, [iter: 461 / all 461], Total Loss: 0.445884, Network_loss:0.228719, CORAL_loss_actual: 0.008788 , MMD_loss_actual : 0.208378
#
# Accuracy of the mnist dataset: 0.972400
# Accuracy of the mnist_m dataset: 0.700922
#
#  epoch: 25, [iter: 461 / all 461], Total Loss: 0.333927, Network_loss:0.164862, CORAL_loss_actual: 0.007198 , MMD_loss_actual : 0.161867
#
# Accuracy of the mnist dataset: 0.964000
# Accuracy of the mnist_m dataset: 0.701144
#
#  epoch: 26, [iter: 461 / all 461], Total Loss: 0.490936, Network_loss:0.269271, CORAL_loss_actual: 0.014542 , MMD_loss_actual : 0.207124
#
# Accuracy of the mnist dataset: 0.972200
# Accuracy of the mnist_m dataset: 0.701589
#
#  epoch: 27, [iter: 461 / all 461], Total Loss: 0.447704, Network_loss:0.253139, CORAL_loss_actual: 0.009407 , MMD_loss_actual : 0.185158
#
# Accuracy of the mnist dataset: 0.973400
# Accuracy of the mnist_m dataset: 0.720364
#
#  epoch: 28, [iter: 461 / all 461], Total Loss: 0.368724, Network_loss:0.187802, CORAL_loss_actual: 0.006390 , MMD_loss_actual : 0.174532
#
# Accuracy of the mnist dataset: 0.969800
# Accuracy of the mnist_m dataset: 0.715254
#
#  epoch: 29, [iter: 461 / all 461], Total Loss: 0.268097, Network_loss:0.116280, CORAL_loss_actual: 0.005776 , MMD_loss_actual : 0.146041
#
# Accuracy of the mnist dataset: 0.972900
# Accuracy of the mnist_m dataset: 0.720031
#
#  epoch: 30, [iter: 461 / all 461], Total Loss: 0.406314, Network_loss:0.180285, CORAL_loss_actual: 0.006936 , MMD_loss_actual : 0.219092
#
# Accuracy of the mnist dataset: 0.969200
# Accuracy of the mnist_m dataset: 0.718587
#
#  epoch: 31, [iter: 461 / all 461], Total Loss: 0.393448, Network_loss:0.172062, CORAL_loss_actual: 0.007315 , MMD_loss_actual : 0.214071
#
# Accuracy of the mnist dataset: 0.971300
# Accuracy of the mnist_m dataset: 0.736918
#
#  epoch: 32, [iter: 461 / all 461], Total Loss: 0.307078, Network_loss:0.174732, CORAL_loss_actual: 0.007074 , MMD_loss_actual : 0.125272
#
# Accuracy of the mnist dataset: 0.974100
# Accuracy of the mnist_m dataset: 0.736363
#
#  epoch: 33, [iter: 461 / all 461], Total Loss: 0.366225, Network_loss:0.184643, CORAL_loss_actual: 0.007625 , MMD_loss_actual : 0.173957
#
# Accuracy of the mnist dataset: 0.971100
# Accuracy of the mnist_m dataset: 0.720476
#
#  epoch: 34, [iter: 461 / all 461], Total Loss: 0.422194, Network_loss:0.188595, CORAL_loss_actual: 0.007138 , MMD_loss_actual : 0.226462
#
# Accuracy of the mnist dataset: 0.975900
# Accuracy of the mnist_m dataset: 0.727586
#
#  epoch: 35, [iter: 461 / all 461], Total Loss: 0.442088, Network_loss:0.214502, CORAL_loss_actual: 0.007179 , MMD_loss_actual : 0.220406
#
# Accuracy of the mnist dataset: 0.977200
# Accuracy of the mnist_m dataset: 0.723586
#
#  epoch: 36, [iter: 461 / all 461], Total Loss: 0.390319, Network_loss:0.206612, CORAL_loss_actual: 0.005818 , MMD_loss_actual : 0.177889
#
# Accuracy of the mnist dataset: 0.975700
# Accuracy of the mnist_m dataset: 0.733807
#
#  epoch: 37, [iter: 461 / all 461], Total Loss: 0.324415, Network_loss:0.198119, CORAL_loss_actual: 0.005422 , MMD_loss_actual : 0.120873
#
# Accuracy of the mnist dataset: 0.977700
# Accuracy of the mnist_m dataset: 0.706699
#
#  epoch: 38, [iter: 461 / all 461], Total Loss: 0.247969, Network_loss:0.111125, CORAL_loss_actual: 0.006448 , MMD_loss_actual : 0.130396
#
# Accuracy of the mnist dataset: 0.977100
# Accuracy of the mnist_m dataset: 0.743140
#
#  epoch: 39, [iter: 461 / all 461], Total Loss: 0.366947, Network_loss:0.208961, CORAL_loss_actual: 0.005388 , MMD_loss_actual : 0.152597
#
# Accuracy of the mnist dataset: 0.979800
# Accuracy of the mnist_m dataset: 0.744140
#
#  epoch: 40, [iter: 461 / all 461], Total Loss: 0.347628, Network_loss:0.124583, CORAL_loss_actual: 0.004730 , MMD_loss_actual : 0.218315
#
# Accuracy of the mnist dataset: 0.974800
# Accuracy of the mnist_m dataset: 0.745028
#
#  epoch: 41, [iter: 461 / all 461], Total Loss: 0.461425, Network_loss:0.234286, CORAL_loss_actual: 0.005739 , MMD_loss_actual : 0.221400
#
# Accuracy of the mnist dataset: 0.978200
# Accuracy of the mnist_m dataset: 0.749139
#
#  epoch: 42, [iter: 461 / all 461], Total Loss: 0.321081, Network_loss:0.156069, CORAL_loss_actual: 0.005450 , MMD_loss_actual : 0.159562
#
# Accuracy of the mnist dataset: 0.978800
# Accuracy of the mnist_m dataset: 0.745917
#
#  epoch: 43, [iter: 461 / all 461], Total Loss: 0.353869, Network_loss:0.166562, CORAL_loss_actual: 0.005418 , MMD_loss_actual : 0.181890
#
# Accuracy of the mnist dataset: 0.977100
# Accuracy of the mnist_m dataset: 0.723031
#
#  epoch: 44, [iter: 461 / all 461], Total Loss: 0.350793, Network_loss:0.159602, CORAL_loss_actual: 0.005992 , MMD_loss_actual : 0.185199
#
# Accuracy of the mnist dataset: 0.977900
# Accuracy of the mnist_m dataset: 0.732585
#
#  epoch: 45, [iter: 461 / all 461], Total Loss: 0.340321, Network_loss:0.156465, CORAL_loss_actual: 0.004545 , MMD_loss_actual : 0.179312
#
# Accuracy of the mnist dataset: 0.977400
# Accuracy of the mnist_m dataset: 0.728586
#
#  epoch: 46, [iter: 461 / all 461], Total Loss: 0.368115, Network_loss:0.119442, CORAL_loss_actual: 0.004480 , MMD_loss_actual : 0.244193
#
# Accuracy of the mnist dataset: 0.979900
# Accuracy of the mnist_m dataset: 0.725808
#
#  epoch: 47, [iter: 461 / all 461], Total Loss: 0.304439, Network_loss:0.191957, CORAL_loss_actual: 0.005568 , MMD_loss_actual : 0.106914
#
# Accuracy of the mnist dataset: 0.976800
# Accuracy of the mnist_m dataset: 0.721586
#
#  epoch: 48, [iter: 461 / all 461], Total Loss: 0.350309, Network_loss:0.150868, CORAL_loss_actual: 0.004682 , MMD_loss_actual : 0.194759
#
# Accuracy of the mnist dataset: 0.977600
# Accuracy of the mnist_m dataset: 0.734807
#
#  epoch: 49, [iter: 461 / all 461], Total Loss: 0.442641, Network_loss:0.254713, CORAL_loss_actual: 0.005619 , MMD_loss_actual : 0.182309
#
# Accuracy of the mnist dataset: 0.976200
# Accuracy of the mnist_m dataset: 0.746473
#
#  epoch: 50, [iter: 461 / all 461], Total Loss: 0.290088, Network_loss:0.162969, CORAL_loss_actual: 0.004601 , MMD_loss_actual : 0.122519
#
# Accuracy of the mnist dataset: 0.977900
# Accuracy of the mnist_m dataset: 0.747584
#
#  epoch: 51, [iter: 461 / all 461], Total Loss: 0.284949, Network_loss:0.144858, CORAL_loss_actual: 0.005112 , MMD_loss_actual : 0.134978
#
# Accuracy of the mnist dataset: 0.978500
# Accuracy of the mnist_m dataset: 0.738251
#
#  epoch: 52, [iter: 461 / all 461], Total Loss: 0.403404, Network_loss:0.179344, CORAL_loss_actual: 0.005736 , MMD_loss_actual : 0.218325
#
# Accuracy of the mnist dataset: 0.979700
# Accuracy of the mnist_m dataset: 0.738918
#
#  epoch: 53, [iter: 461 / all 461], Total Loss: 0.699983, Network_loss:0.265262, CORAL_loss_actual: 0.004490 , MMD_loss_actual : 0.430231
#
# Accuracy of the mnist dataset: 0.980700
# Accuracy of the mnist_m dataset: 0.732807
#
#  epoch: 54, [iter: 461 / all 461], Total Loss: 0.430985, Network_loss:0.138984, CORAL_loss_actual: 0.004892 , MMD_loss_actual : 0.287108
#
# Accuracy of the mnist dataset: 0.980700
# Accuracy of the mnist_m dataset: 0.734030
#
#  epoch: 55, [iter: 461 / all 461], Total Loss: 0.401648, Network_loss:0.197377, CORAL_loss_actual: 0.003579 , MMD_loss_actual : 0.200691
#
# Accuracy of the mnist dataset: 0.980600
# Accuracy of the mnist_m dataset: 0.729586
#
#  epoch: 56, [iter: 461 / all 461], Total Loss: 0.460925, Network_loss:0.225793, CORAL_loss_actual: 0.004729 , MMD_loss_actual : 0.230403
#
# Accuracy of the mnist dataset: 0.980300
# Accuracy of the mnist_m dataset: 0.718142
#
#  epoch: 57, [iter: 461 / all 461], Total Loss: 0.338004, Network_loss:0.115622, CORAL_loss_actual: 0.004344 , MMD_loss_actual : 0.218039
#
# Accuracy of the mnist dataset: 0.979800
# Accuracy of the mnist_m dataset: 0.736696
#
#  epoch: 58, [iter: 461 / all 461], Total Loss: 0.333329, Network_loss:0.086062, CORAL_loss_actual: 0.004946 , MMD_loss_actual : 0.242321
#
# Accuracy of the mnist dataset: 0.979300
# Accuracy of the mnist_m dataset: 0.742473
#
#  epoch: 59, [iter: 461 / all 461], Total Loss: 0.335128, Network_loss:0.178878, CORAL_loss_actual: 0.003805 , MMD_loss_actual : 0.152445
#
# Accuracy of the mnist dataset: 0.978800
# Accuracy of the mnist_m dataset: 0.747028
#
#  epoch: 60, [iter: 461 / all 461], Total Loss: 0.370809, Network_loss:0.216113, CORAL_loss_actual: 0.004044 , MMD_loss_actual : 0.150652
#
# Accuracy of the mnist dataset: 0.979100
# Accuracy of the mnist_m dataset: 0.752139
#
#  epoch: 61, [iter: 461 / all 461], Total Loss: 0.287393, Network_loss:0.167610, CORAL_loss_actual: 0.005146 , MMD_loss_actual : 0.114636
#
# Accuracy of the mnist dataset: 0.980000
# Accuracy of the mnist_m dataset: 0.753361
#
#  epoch: 62, [iter: 461 / all 461], Total Loss: 0.386977, Network_loss:0.213770, CORAL_loss_actual: 0.004592 , MMD_loss_actual : 0.168614
#
# Accuracy of the mnist dataset: 0.978800
# Accuracy of the mnist_m dataset: 0.739473
#
#  epoch: 63, [iter: 461 / all 461], Total Loss: 0.321616, Network_loss:0.156389, CORAL_loss_actual: 0.004566 , MMD_loss_actual : 0.160661
#
# Accuracy of the mnist dataset: 0.974400
# Accuracy of the mnist_m dataset: 0.729475
#
#  epoch: 64, [iter: 461 / all 461], Total Loss: 0.338987, Network_loss:0.137777, CORAL_loss_actual: 0.004763 , MMD_loss_actual : 0.196447
#
# Accuracy of the mnist dataset: 0.980400
# Accuracy of the mnist_m dataset: 0.738474
#
#  epoch: 65, [iter: 461 / all 461], Total Loss: 0.376332, Network_loss:0.106418, CORAL_loss_actual: 0.005579 , MMD_loss_actual : 0.264335
#
# Accuracy of the mnist dataset: 0.978500
# Accuracy of the mnist_m dataset: 0.753250
#
#  epoch: 66, [iter: 461 / all 461], Total Loss: 0.299822, Network_loss:0.088645, CORAL_loss_actual: 0.004892 , MMD_loss_actual : 0.206285
#
# Accuracy of the mnist dataset: 0.980700
# Accuracy of the mnist_m dataset: 0.735474
#
#  epoch: 67, [iter: 461 / all 461], Total Loss: 0.290075, Network_loss:0.107750, CORAL_loss_actual: 0.004942 , MMD_loss_actual : 0.177383
#
# Accuracy of the mnist dataset: 0.981400
# Accuracy of the mnist_m dataset: 0.751694
#
#  epoch: 68, [iter: 461 / all 461], Total Loss: 0.375605, Network_loss:0.187436, CORAL_loss_actual: 0.004444 , MMD_loss_actual : 0.183725
#
# Accuracy of the mnist dataset: 0.981900
# Accuracy of the mnist_m dataset: 0.741918
#
#  epoch: 69, [iter: 461 / all 461], Total Loss: 0.297856, Network_loss:0.133153, CORAL_loss_actual: 0.003491 , MMD_loss_actual : 0.161211
#
# Accuracy of the mnist dataset: 0.983200
# Accuracy of the mnist_m dataset: 0.747695
#
#  epoch: 70, [iter: 461 / all 461], Total Loss: 0.372730, Network_loss:0.181556, CORAL_loss_actual: 0.004023 , MMD_loss_actual : 0.187151
#
# Accuracy of the mnist dataset: 0.980000
# Accuracy of the mnist_m dataset: 0.742695
#
#  epoch: 71, [iter: 461 / all 461], Total Loss: 0.337660, Network_loss:0.134929, CORAL_loss_actual: 0.003737 , MMD_loss_actual : 0.198994
#
# Accuracy of the mnist dataset: 0.981000
# Accuracy of the mnist_m dataset: 0.723142
#
#  epoch: 72, [iter: 461 / all 461], Total Loss: 0.308411, Network_loss:0.176535, CORAL_loss_actual: 0.004587 , MMD_loss_actual : 0.127289
#
# Accuracy of the mnist dataset: 0.982600
# Accuracy of the mnist_m dataset: 0.743362
#
#  epoch: 73, [iter: 461 / all 461], Total Loss: 0.320543, Network_loss:0.130069, CORAL_loss_actual: 0.003907 , MMD_loss_actual : 0.186567
#
# Accuracy of the mnist dataset: 0.981400
# Accuracy of the mnist_m dataset: 0.734696
#
#  epoch: 74, [iter: 461 / all 461], Total Loss: 0.429782, Network_loss:0.194592, CORAL_loss_actual: 0.004963 , MMD_loss_actual : 0.230227
#
# Accuracy of the mnist dataset: 0.981600
# Accuracy of the mnist_m dataset: 0.749139
#
#  epoch: 75, [iter: 461 / all 461], Total Loss: 0.335292, Network_loss:0.194092, CORAL_loss_actual: 0.003683 , MMD_loss_actual : 0.137517
#
# Accuracy of the mnist dataset: 0.982800
# Accuracy of the mnist_m dataset: 0.747361
#
#  epoch: 76, [iter: 461 / all 461], Total Loss: 0.361250, Network_loss:0.159513, CORAL_loss_actual: 0.003974 , MMD_loss_actual : 0.197763
#
# Accuracy of the mnist dataset: 0.983400
# Accuracy of the mnist_m dataset: 0.737251
#
#  epoch: 77, [iter: 461 / all 461], Total Loss: 0.349589, Network_loss:0.128730, CORAL_loss_actual: 0.005007 , MMD_loss_actual : 0.215852
#
# Accuracy of the mnist dataset: 0.981400
# Accuracy of the mnist_m dataset: 0.743029
#
#  epoch: 78, [iter: 461 / all 461], Total Loss: 0.369681, Network_loss:0.186913, CORAL_loss_actual: 0.003315 , MMD_loss_actual : 0.179453
#
# Accuracy of the mnist dataset: 0.979400
# Accuracy of the mnist_m dataset: 0.747917
#
#  epoch: 79, [iter: 461 / all 461], Total Loss: 0.396507, Network_loss:0.198146, CORAL_loss_actual: 0.003767 , MMD_loss_actual : 0.194595
#
# Accuracy of the mnist dataset: 0.981000
# Accuracy of the mnist_m dataset: 0.730030
#
#  epoch: 80, [iter: 461 / all 461], Total Loss: 0.288384, Network_loss:0.161571, CORAL_loss_actual: 0.005219 , MMD_loss_actual : 0.121593
#
# Accuracy of the mnist dataset: 0.981100
# Accuracy of the mnist_m dataset: 0.740140
#
#  epoch: 81, [iter: 461 / all 461], Total Loss: 0.237898, Network_loss:0.084308, CORAL_loss_actual: 0.003825 , MMD_loss_actual : 0.149765
#
# Accuracy of the mnist dataset: 0.980400
# Accuracy of the mnist_m dataset: 0.737807
#
# ============ Summary =============
#
# Accuracy of the mnist dataset: 0.980000
# Accuracy of the mnist_m dataset: 0.753361
# Corresponding model was save in ./out_ex3_cnn_da/mnist_mnistm_model_epoch_best.pth
# Save dict to ./out_ex3_cnn_da/losses.pkl

# %%
print('============ Summary ============= \n')
print('Accuracy of the %s dataset: %f' % ('mnist', max(losses['test']['acc_bw'])))
print('Accuracy of the %s dataset: %f' % ('mnist_m', max(losses['test']['acc_color'])))
print('Corresponding model was saved into ' + model_root + '/mnist_mnistm_model_epoch_best.pth')
# Out:
# ============ Summary =============
#
# Accuracy of the mnist dataset: 0.983800
# Accuracy of the mnist_m dataset: 0.790579
# Corresponding model was saved into ./out_ex3_cnn_da/mnist_mnistm_model_epoch_best.pth

# %%
#!pwd
# Out:
# /content/dda_pytorch

# %%
#cd /content/dda_pytorch/out_ex3_cnn_da/
# Out:
# /content/dda_pytorch/out_ex3_cnn_da

# %%
#!mv '/content/dda_pytorch/out_ex3_cnn_da/mnist_mnistm_model_epoch_best.pth' '/content/drive/MyDrive/CV'

# %%
#!mv '/content/dda_pytorch/out_ex3_cnn_da/mnist_mnistm_model_epoch_current.pth' '/content/drive/MyDrive/CV'
