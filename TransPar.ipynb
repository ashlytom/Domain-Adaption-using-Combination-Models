# %%
# !git clone https://github.com/zhyhan/TransPar.git
# Out:
# Cloning into 'TransPar'...
# remote: Enumerating objects: 226, done.
# remote: Counting objects: 100% (226/226), done.
# remote: Compressing objects: 100% (185/185), done.
# remote: Total 226 (delta 36), reused 225 (delta 35), pack-reused 0
# Receiving objects: 100% (226/226), 760.55 KiB | 19.01 MiB/s, done.
# Resolving deltas: 100% (36/36), done.

# %%
cd /content/TransPar/examples/domain_adaptation/classification
# Out:
# /content/TransPar/examples/domain_adaptation/classification

# %%
# !python dann-TransPar.py
# Out:
# usage: dann-TransPar.py [-h] [-d DATA] [-s SOURCE] [-t TARGET] [--center-crop]
#                         [-a ARCH] [--bottleneck-dim BOTTLENECK_DIM]
#                         [--trade-off TRADE_OFF] [-b N] [--lr LR]
#                         [--lr-gamma LR_GAMMA] [--lr-decay LR_DECAY]
#                         [--momentum M] [--wd W] [-j N] [--epochs N]
#                         [-i ITERS_PER_EPOCH] [--keep_ratio W] [-p N]
#                         [--seed SEED] [--per-class-eval] [--log LOG]
#                         [--phase {train,test,analysis}]
#                         DIR
# dann-TransPar.py: error: the following arguments are required: DIR

# %% [markdown]
# To add dataset to run the examples- add them in this file "/content/TransPar/examples/domain_adaptation/classification/data"
#
# This code autodownloads the data

# %%
#!python dann-TransPar.py data/office31 -d Office31 -s A -t D -a resnet50  --epochs 5
# Out:
# Namespace(arch='resnet50', batch_size=32, bottleneck_dim=256, center_crop=False, data='Office31', epochs=5, iters_per_epoch=1000, keep_ratio=0.5, log='dann', lr=0.01, lr_decay=0.75, lr_gamma=0.001, momentum=0.9, per_class_eval=False, phase='train', print_freq=100, root='data/office31', seed=None, source='A', target='D', trade_off=1.0, weight_decay=0.001, workers=2)
# ...
# 13312it [00:00, 320078.97it/s]
# Extracting data/office31/image_list.zip to data/office31
# ...
# 20449280it [00:02, 8899898.86it/s]
# Extracting data/office31/amazon.tgz to data/office31
# ...
# 36199424it [00:03, 11241178.10it/s]
# Extracting data/office31/dslr.tgz to data/office31
# ...
# 20608000it [00:02, 8941366.51it/s]
# Extracting data/office31/webcam.tgz to data/office31
# => using pre-trained model 'resnet50'
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|##########| 97.8M/97.8M [00:00<00:00, 204MB/s]
# Keep ratio = 0.5
# ...

# %%
# A-Amazon , D-dslr, W-Webcam

# %% [markdown]
# Needs a powerful GPU

# %%
#!python dann-TransPar.py data/office31 -d Office31 -s A -t W -a resnet50  --epochs 5
#!python dann-TransPar.py data/office31 -d Office31 -s W -t A -a resnet50  --epochs 5
#!python dann-TransPar.py data/office31 -d Office31 -s W -t D -a resnet50  --epochs 5
# !python dann-TransPar.py data/office31 -d Office31 -s D -t A -a resnet50  --epochs 5
# !python dann-TransPar.py data/office31 -d Office31 -s D -t W -a resnet50  --epochs 5
# Out:
# Namespace(arch='resnet50', batch_size=32, bottleneck_dim=256, center_crop=False, data='Office31', epochs=5, iters_per_epoch=1000, keep_ratio=0.5, log='dann', lr=0.01, lr_decay=0.75, lr_gamma=0.001, momentum=0.9, per_class_eval=False, phase='train', print_freq=100, root='data/office31', seed=None, source='D', target='A', trade_off=1.0, weight_decay=0.001, workers=2)
# ...
# 13312it [00:00, 289694.58it/s]
# Extracting data/office31/image_list.zip to data/office31
# ...
# 20449280it [00:02, 7743415.98it/s]
# Extracting data/office31/amazon.tgz to data/office31
# ...
# 36199424it [00:03, 10057464.67it/s]
# Extracting data/office31/dslr.tgz to data/office31
# ...
# 20608000it [00:02, 8624755.89it/s]
# Extracting data/office31/webcam.tgz to data/office31
# => using pre-trained model 'resnet50'
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|##########| 97.8M/97.8M [00:00<00:00, 216MB/s]
# Keep ratio = 0.5
# ...
