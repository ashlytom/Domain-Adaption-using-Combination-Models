# %%
# !git clone https://github.com/swag-kaust/dda_pytorch.git
# Out:
# Cloning into 'dda_pytorch'...
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 66 (delta 27), reused 51 (delta 15), pack-reused 0
# Unpacking objects: 100% (66/66), done.

# %%
cd /content/dda_pytorch
# Out:
# /content/dda_pytorch

# %%
import os
import sys
import tqdm
import random
import numpy as np
#Fouerir tranform??
from numpy.fft import rfft2, irfft2, fftshift, ifftshift

import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.nn as nn
import torch.utils.data
from torchvision import datasets
from torchvision import transforms

from components.data_loader import GetLoader
from components.model import CNNModel
from components.test import test
import components.shared as sd

# %%
# Paths to datasets
source_dataset_name = 'MNIST'
target_dataset_name = 'mnist_m'
source_image_root = os.path.join('dataset', source_dataset_name)
target_image_root = os.path.join('dataset', target_dataset_name)
os.makedirs('./dataset', exist_ok=True)

# Where to save outputs
model_root = './out_ex3_cnn_da'
os.makedirs(model_root, exist_ok=True)

# %%
cuda = True
cudnn.benchmark = True

# Hyperparameters
lr = 1e-3
batch_size = 128
image_size = 28
n_epoch = 100

# manual_seed = random.randint(1, 10000)
manual_seed = 222
random.seed(manual_seed)
torch.manual_seed(manual_seed)
print(f'Random seed: {manual_seed}')
# Out:
# Random seed: 222

# %%
import tarfile
my_tar = tarfile.open('/content/drive/MyDrive/Colab Notebooks/Thesis Domain adaptation/Datasets/mnist_m (1).tar')
my_tar.extractall('/content/dda_pytorch/dataset') # specify which folder to extract to
my_tar.close()

# %%
# Transformations / augmentations
img_transform_source = transforms.Compose([
    transforms.Resize(image_size),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.1307,), std=(0.3081,)),
    transforms.Lambda(lambda x: x.repeat(3, 1, 1)),
])

img_transform_target = transforms.Compose([
    transforms.Resize(image_size),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
])

# Load MNIST dataset
dataset_source = datasets.MNIST(
    root='dataset',
    train=True,
    transform=img_transform_source,
    download=True
)

# Load MNIST-M dataset
train_list = os.path.join(target_image_root, 'mnist_m_train_labels.txt')
dataset_target = GetLoader(
    data_root=os.path.join(target_image_root, 'mnist_m_train'),
    data_list=train_list,
    transform=img_transform_target
)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to dataset/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting dataset/MNIST/raw/train-images-idx3-ubyte.gz to dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to dataset/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting dataset/MNIST/raw/train-labels-idx1-ubyte.gz to dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to dataset/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting dataset/MNIST/raw/t10k-images-idx3-ubyte.gz to dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz to dataset/MNIST/raw

# %%
def get_global_acorr_for_loader(loader):
    """ The average auto-correlation of all images in the dataset """
    global_acorr = np.zeros((3, 28, 15), dtype=np.complex128)
    prog_bar = tqdm.tqdm(loader)
    for data, _ in prog_bar:
        data_f = np.fft.rfft2(data, s=data.shape[-2:], axes=(-2, -1))
        # Auto-correlation is multiplication with the conjucate of self
        # in frequency domain
        global_acorr += data_f * np.conjugate(data_f)
    global_acorr /= len(loader)
    print(global_acorr.shape)
    return np.fft.fftshift(global_acorr)

def route_to(fname):
    """ Shortcut for routing to the save folder """
    return os.path.join(model_root, fname)

# Compute global acorr if not in the folder, load otherwise
if not 'gacorr_dst_tr.npy' in os.listdir(model_root):
    print('Save global acorr')
    gacorr_dst_tr = get_global_acorr_for_loader(dataset_target)
    gacorr_src_tr = get_global_acorr_for_loader(dataset_source)
    np.save(route_to('gacorr_dst_tr.npy'), gacorr_dst_tr)
    np.save(route_to('gacorr_src_tr.npy'), gacorr_src_tr)
else:
    print('Load global acorr')
    gacorr_dst_tr = np.load(route_to('gacorr_dst_tr.npy'))
    gacorr_src_tr = np.load(route_to('gacorr_src_tr.npy'))
# Out:
# Save global acorr
# 100%|██████████| 59001/59001 [00:39<00:00, 1500.01it/s]
# (3, 28, 15)
# 100%|██████████| 60000/60000 [00:22<00:00, 2621.72it/s]
# (3, 28, 15)

# %%
# Window size
crop_size = 1
print(f'Use the crop size for xcorr = {crop_size}')
# Out:
# Use the crop size for xcorr = 1

# %%
def crop_ref(x, n=1, edge=5):
    """Crop a window from the image
    Args:
        x(np.ndarray): image [c, h, w]
        n(int): window size
        edge(int): margin to avoid from edges of the image
    """
    if n % 2 == 0: n+=1;
    k = int((n - 1) / 2)
    nz, nx = x.shape[-2:]
    dim1 = np.random.randint(0+k+edge, nz-k-edge)
    dim2 = np.random.randint(0+k, nx-k)
    out = x[..., dim1-k:dim1+k+1, dim2-k:dim2+k+1]
    return out

# crop_ref(np.ones((2, 100, 100)), n=5).shape

# %%
def get_global_xcorr_for_loader(loader, crop_size=1):
    # Init the placeholder for average
    rand_pixel = np.zeros((3, crop_size, crop_size))
    
    # Loop over all images in the dataset
    prog_bar = tqdm.tqdm(loader)
    for data, _ in prog_bar:
        rand_pixel += np.mean(crop_ref(data, crop_size).numpy(), axis=0)
    rand_pixel /= len(loader)
    
    # Place the mean pixel into center of an empty image
    c, h ,w = data.shape
    mid_h, mid_w = int(h // 2), int(w // 2)
    embed = np.zeros_like(data)
    embed[..., mid_h:mid_h+1, mid_w:mid_w+1] = rand_pixel
    global_xcorr = np.fft.rfft2(embed, s=data.shape[-2:], axes=(-2, -1))
    return np.fft.fftshift(global_xcorr)


# Compute global xcorr if not in the folder, load otherwise
if not 'gxcorr_dst_tr.npy' in os.listdir(model_root):
# if True:
    print('Save global xcorr')
    gxcorr_dst_tr = get_global_xcorr_for_loader(dataset_target, crop_size)
    gxcorr_src_tr = get_global_xcorr_for_loader(dataset_source, crop_size)
    np.save(route_to('gxcorr_dst_tr.npy'), gxcorr_dst_tr)
    np.save(route_to('gxcorr_src_tr.npy'), gxcorr_src_tr)
else:
    print('Load global xcorr')
    gxcorr_dst_tr = np.load(route_to('gxcorr_dst_tr.npy'))
    gxcorr_src_tr = np.load(route_to('gxcorr_src_tr.npy'))
# Out:
# Save global xcorr
# 100%|██████████| 59001/59001 [00:36<00:00, 1595.69it/s]
# 100%|██████████| 60000/60000 [00:21<00:00, 2771.94it/s]

# %%
def flip_channels(x):
    """Reverse polarity of random channels"""
    flip_matrix = np.random.choice([-1, 1], 3)[..., np.newaxis, np.newaxis] 
    return (x * flip_matrix).astype(np.float32)

def shuffle_channels(x):
    """Change order of channels"""
    return np.random.permutation(x)

def normalize_channels(x):
    """Map data to [-1,1] range. The scaling after conv(xcorr, acorr) is not 
    suitable for image processing so this function fixes it"""
    cmin = np.min(x, axis=(-2,-1))[..., np.newaxis, np.newaxis]
    x -= cmin
    cmax = np.max(np.abs(x), axis=(-2,-1))[..., np.newaxis, np.newaxis]
    x /= cmax
    x *= 2
    x -= 1
    return x.astype(np.float32)

# %%
class DDALoaderTrain(torch.utils.data.Dataset):
    def __init__(self, loader1, avg_acorr2, p=0.5, crop_size=1):
        super().__init__()
        self.loader1 = loader1
        self.avg_acorr2 = avg_acorr2
        self.p = p
        self.crop_size = crop_size
        
    def __len__(self):
        return len(self.loader1)
        
    def __getitem__(self, item):
        # Get main data (data, label)
        data, label = self.loader1.__getitem__(item)
        data_fft = fftshift(rfft2(data, s=data.shape[-2:], axes=(-2, -1)))
        
        # Get random pixel from another data from the same dataset
        random_index = np.random.randint(0, len(self.loader1))
        another_data, _ = self.loader1.__getitem__(random_index)
        rand_pixel = crop_ref(another_data, self.crop_size)
        
        # Convert to Fourier domain
        c, h ,w = another_data.shape
        mid_h, mid_w = int(h // 2), int(w // 2)
        embed = np.zeros_like(another_data)
        embed[:, mid_h:mid_h+1, mid_w:mid_w+1] = rand_pixel
        pixel_fft = np.fft.rfft2(embed, s=another_data.shape[-2:], axes=(-2, -1))
        pixel_fft = np.fft.fftshift(pixel_fft)
            
        # Cross-correlate the data sample with the random pixel from the same dataset
        xcorr = data_fft * np.conjugate(pixel_fft)

        # Convolve the ruslt with the auto-correlation of another dataset
        conv = xcorr * self.avg_acorr2

        # Reverse Fourier domain and map channels to [-1, 1] range
        data_da = fftshift(irfft2(ifftshift(conv), axes=(-2, -1)))
        data_da = normalize_channels(data_da)
        
        # Apply data augmentations
        if np.random.rand() < self.p:
            data_da = flip_channels(data_da)
        if np.random.rand() < self.p:
            data_da = shuffle_channels(data_da)
            
        # Return a pair of data / label
        return data_da.astype(np.float32), label

# %%
dataset_source = DDALoaderTrain(dataset_source, gacorr_dst_tr)
dataset_target = DDALoaderTrain(dataset_target, gacorr_src_tr)

dummy_data, dummy_label = dataset_source.__getitem__(0)
print('Image shape: {}\t Label: {}'.format(dummy_data.shape, dummy_label))
# Out:
# Image shape: (3, 28, 28)	 Label: 5

# %%
class DDALoaderTest(torch.utils.data.Dataset):
    def __init__(self, loader1, avg_acorr2, avg_xcorr1):
        super().__init__()
        self.loader1 = loader1
        self.avg_acorr2 = avg_acorr2
        self.avg_xcorr1 = avg_xcorr1
        
    def __len__(self):
        return len(self.loader1)
        
    def __getitem__(self, item):
        data, label = self.loader1.__getitem__(item)
        data_fft = fftshift(rfft2(data, s=data.shape[-2:], axes=(-2, -1)))
        
        xcorr = data_fft * np.conjugate(self.avg_xcorr1)
        conv = xcorr * self.avg_acorr2

        data_da = fftshift(irfft2(ifftshift(conv), axes=(-2, -1)))
        data_da = normalize_channels(data_da)
        return data_da.astype(np.float32), label

# %%
def test(dataset_name, model_root, crop_size=1):
    image_root = os.path.join('dataset', dataset_name)  
    if dataset_name == 'mnist_m':
        test_list = os.path.join(image_root, 'mnist_m_test_labels.txt')
        dataset = GetLoader(
            data_root=os.path.join(image_root, 'mnist_m_test'),
            data_list=test_list,
            transform=img_transform_target
        )
        
        if not 'gxcorr_dst_te.npy' in os.listdir(model_root):
            print('Save global acorr and xcorr')
            # acorr
            gacorr_src_te = get_global_acorr_for_loader(dataset)
            np.save(route_to('gacorr_src_te.npy'), gacorr_src_te)
            # xcorr
            gxcorr_dst_te = get_global_xcorr_for_loader(dataset, crop_size)
            np.save(route_to('gxcorr_dst_te.npy'), gxcorr_dst_te)
        else:
            gacorr_src_te = np.load(route_to('gacorr_src_te.npy'))
            gxcorr_dst_te = np.load(route_to('gxcorr_dst_te.npy'))
            
        # Init loader for MNIST-M
        dataset = DDALoaderTest(dataset, gacorr_src_te, gxcorr_dst_te)
    else:
        dataset = datasets.MNIST(
            root='dataset',
            train=False,
            transform=img_transform_source,
        )
        if not 'gxcorr_src_te.npy' in os.listdir(model_root):
            print('Save global acorr and xcorr')
            # acorr
            gacorr_dst_te = get_global_acorr_for_loader(dataset)
            np.save(route_to('gacorr_dst_te.npy'), gacorr_dst_te)
            # xcorr
            gxcorr_src_te = get_global_xcorr_for_loader(dataset, crop_size)
            np.save(route_to('gxcorr_src_te.npy'), gxcorr_src_te)
        else:
            gacorr_dst_te = np.load(route_to('gacorr_dst_te.npy'))
            gxcorr_src_te = np.load(route_to('gxcorr_src_te.npy'))
            
        # Init loader for MNIST
        dataset = DDALoaderTest(dataset, gacorr_dst_te, gxcorr_src_te)

    dataloader = torch.utils.data.DataLoader(
        dataset=dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=8
    )

    """ test """
    my_net = torch.load(os.path.join(model_root, 'mnist_mnistm_model_epoch_current.pth'))
    my_net = my_net.eval()

    if cuda:
        my_net = my_net.cuda()

    len_dataloader = len(dataloader)
    data_target_iter = iter(dataloader)

    i = 0
    n_total = 0
    n_correct = 0

    while i < len_dataloader:
        # test model using target data
        data_target = data_target_iter.next()
        t_img, t_label = data_target

        _batch_size = len(t_label)

        if cuda:
            t_img = t_img.cuda()
            t_label = t_label.cuda()

        class_output, _ , _= my_net(input_data=t_img, alpha=0)
        pred = class_output.data.max(1, keepdim=True)[1]
        n_correct += pred.eq(t_label.data.view_as(pred)).cpu().sum()
        n_total += _batch_size
        i += 1

    accu = n_correct.data.numpy() * 1.0 / n_total
    return accu

# %%
dataloader_source = torch.utils.data.DataLoader(
    dataset=dataset_source,
    batch_size=batch_size,
    shuffle=True,
    num_workers=8)

dataloader_target = torch.utils.data.DataLoader(
    dataset=dataset_target,
    batch_size=batch_size,
    shuffle=True,
    num_workers=8)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        self.feature = nn.Sequential()
        self.feature.add_module('f_conv1', nn.Conv2d(3, 64, kernel_size=5))
        self.feature.add_module('f_bn1', nn.BatchNorm2d(64))
        self.feature.add_module('f_pool1', nn.MaxPool2d(2))
        self.feature.add_module('f_relu1', nn.ReLU(True))
        self.feature.add_module('f_conv2', nn.Conv2d(64, 50, kernel_size=5))
        self.feature.add_module('f_bn2', nn.BatchNorm2d(50))
        self.feature.add_module('f_drop1', nn.Dropout2d())
        self.feature.add_module('f_pool2', nn.MaxPool2d(2))
        self.feature.add_module('f_relu2', nn.ReLU(True))

        self.class_classifier = nn.Sequential()
        self.class_classifier.add_module('c_fc1', nn.Linear(50 * 4 * 4, 3000))
        self.class_classifier.add_module('c_bn1', nn.BatchNorm1d(3000))
        self.class_classifier.add_module('c_relu1', nn.ReLU(True))
        self.class_classifier.add_module('c_drop1', nn.Dropout())

        self.extraction = nn.Sequential()
        self.extraction.add_module('c_fc2', nn.Linear(3000, 4000))
        self.extraction.add_module('c_bn2', nn.BatchNorm1d(4000))
        self.extraction.add_module('c_relu2', nn.ReLU(True))

        self.original_class = nn.Sequential()
        self.original_class.add_module('c_fc3', nn.Linear(4000, 10))
        self.original_class.add_module('c_softmax', nn.LogSoftmax(dim=1))

    def forward(self, input_data, alpha):
        input_data = input_data.expand(input_data.data.shape[0], 3, 28, 28)
        feature = self.feature(input_data)
        feature = feature.view(-1, 50 * 4 * 4)
        inter_1 = self.class_classifier(feature)
        inter_2 = self.extraction(inter_1)
        class_output = self.original_class(inter_2)

        return class_output, 0, inter_2

# %%
def CORAL(source, target):
    d = source.size(1)
    ns, nt = source.size(0), target.size(0)

    # source covariance
    tmp_s = torch.ones((1, ns)).cuda() @ source
    cs = (source.t() @ source - (tmp_s.t() @ tmp_s) / ns) / (ns - 1)

    # target covariance
    tmp_t = torch.ones((1, nt)).cuda() @ target
    ct = (target.t() @ target - (tmp_t.t() @ tmp_t) / nt) / (nt - 1)

    # frobenius norm
    loss = (cs - ct).pow(2).sum().sqrt()
    loss = loss / (4 * d * d)

    return loss

# %%
# load model
my_net = CNNModel()

# setup optimizer
optimizer = optim.Adam(my_net.parameters(), lr=lr)

loss_class = torch.nn.NLLLoss()

if cuda:
    my_net = my_net.cuda()
    loss_class = loss_class.cuda()

for p in my_net.parameters():
    p.requires_grad = True

# %%
# Record losses for each epoch (used in compare.ipynb)
losses = {'test': {'acc_bw': [], 'acc_color': []}}
name_losses = 'losses.pkl'
lamba = 10000000

# %%
early_stop = 20

# %%
if not name_losses in os.listdir(model_root):
    stop = 0
# if True:
    # training
    best_accu_t = 0.0
    for epoch in range(n_epoch):
        stop += 1

        len_dataloader = min(len(dataloader_source), len(dataloader_target))
        data_source_iter = iter(dataloader_source)
        data_target_iter = iter(dataloader_target)

        for i in range(len_dataloader):

            p = float(i + epoch * len_dataloader) / n_epoch / len_dataloader
            alpha = 2. / (1. + np.exp(-10 * p)) - 1

            # training model using source data
            data_source = data_source_iter.next()
            s_img, s_label = data_source

            # for target data
            data_target = data_target_iter.next()
            t_img, _ = data_target

            my_net.zero_grad()
            batch_size = len(s_label)

            if cuda:
                s_img = s_img.cuda()
                s_label = s_label.cuda()
                t_img = t_img.cuda()

            class_output, _ , src1 = my_net(input_data=s_img, alpha=alpha)
            _, _ , trg1 = my_net(input_data=t_img, alpha=alpha)

            #CORAL Loss
            
            coral_loss1 = CORAL(src1 , trg1)
            
            coral1 = lamba*coral_loss1
            
            actual_coral = coral1 

            #Network loss
            network_loss = loss_class(class_output, s_label)

            #Combination            
            err_s_label = network_loss + actual_coral

            

            err = err_s_label
            err.backward()
            optimizer.step()

            sys.stdout.write('\r epoch: %d, [iter: %d / all %d], Total Loss: %f, Network_loss:%f, CORAL_loss_actual: %f ' \
                  % (epoch, i + 1, len_dataloader, err_s_label.data.cpu().numpy(), network_loss.data.cpu().numpy() ,actual_coral.data.cpu().numpy()))
            sys.stdout.flush()
            torch.save(my_net, '{0}/mnist_mnistm_model_epoch_current.pth'.format(model_root))

        print('\n')
        accu_s = test(source_dataset_name, model_root)
        print('Accuracy of the %s dataset: %f' % ('mnist', accu_s))
        accu_t = test(target_dataset_name, model_root)
        print('Accuracy of the %s dataset: %f\n' % ('mnist_m', accu_t))

        losses['test']['acc_bw'].append(accu_s)
        losses['test']['acc_color'].append(accu_t)

        if accu_t > best_accu_t:
            best_accu_s = accu_s
            best_accu_t = accu_t
            torch.save(my_net, '{0}/mnist_mnistm_model_epoch_best.pth'.format(model_root))
            stop = 0
        if stop >= early_stop:
          break

    print('============ Summary ============= \n')
    print('Accuracy of the %s dataset: %f' % ('mnist', best_accu_s))
    print('Accuracy of the %s dataset: %f' % ('mnist_m', best_accu_t))
    print('Corresponding model was save in ' + model_root + '/mnist_mnistm_model_epoch_best.pth')
    sd.save_dict(os.path.join(model_root, 'losses.pkl'), losses)
else:
    path_losses = os.path.join(model_root, name_losses)
    print(f'Losses from previous run found!')
    losses = sd.load_dict(path_losses)
    sd.plot_curves(losses)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#  epoch: 0, [iter: 461 / all 461], Total Loss: 2.528988, Network_loss:1.690390, CORAL_loss_actual: 0.838598
#
# Save global acorr and xcorr
# 100%|██████████| 10000/10000 [00:03<00:00, 2511.58it/s]
# (3, 28, 15)
# 100%|██████████| 10000/10000 [00:03<00:00, 2709.12it/s]
# Accuracy of the mnist dataset: 0.114200
# Save global acorr and xcorr
# 100%|██████████| 9001/9001 [00:09<00:00, 996.00it/s]
# (3, 28, 15)
# 100%|██████████| 9001/9001 [00:05<00:00, 1555.99it/s]
# Accuracy of the mnist_m dataset: 0.233419
#
#  epoch: 1, [iter: 461 / all 461], Total Loss: 1.259979, Network_loss:1.119945, CORAL_loss_actual: 0.140034
#
# Accuracy of the mnist dataset: 0.522900
# Accuracy of the mnist_m dataset: 0.376180
#
#  epoch: 2, [iter: 461 / all 461], Total Loss: 0.661071, Network_loss:0.520722, CORAL_loss_actual: 0.140349
#
# Accuracy of the mnist dataset: 0.700200
# Accuracy of the mnist_m dataset: 0.456505
#
#  epoch: 3, [iter: 461 / all 461], Total Loss: 0.592070, Network_loss:0.428513, CORAL_loss_actual: 0.163556
#
# Accuracy of the mnist dataset: 0.849400
# Accuracy of the mnist_m dataset: 0.518831
#
#  epoch: 4, [iter: 461 / all 461], Total Loss: 0.467862, Network_loss:0.310414, CORAL_loss_actual: 0.157448
#
# Accuracy of the mnist dataset: 0.895300
# Accuracy of the mnist_m dataset: 0.550050
#
#  epoch: 5, [iter: 461 / all 461], Total Loss: 0.291848, Network_loss:0.216016, CORAL_loss_actual: 0.075831
#
# Accuracy of the mnist dataset: 0.916500
# Accuracy of the mnist_m dataset: 0.577714
#
#  epoch: 6, [iter: 461 / all 461], Total Loss: 0.341891, Network_loss:0.255692, CORAL_loss_actual: 0.086199
#
# Accuracy of the mnist dataset: 0.936900
# Accuracy of the mnist_m dataset: 0.608710
#
#  epoch: 7, [iter: 461 / all 461], Total Loss: 0.267154, Network_loss:0.205454, CORAL_loss_actual: 0.061701
#
# Accuracy of the mnist dataset: 0.944200
# Accuracy of the mnist_m dataset: 0.617154
#
#  epoch: 8, [iter: 461 / all 461], Total Loss: 0.228850, Network_loss:0.182209, CORAL_loss_actual: 0.046641
#
# Accuracy of the mnist dataset: 0.954800
# Accuracy of the mnist_m dataset: 0.626486
#
#  epoch: 9, [iter: 461 / all 461], Total Loss: 0.138566, Network_loss:0.094063, CORAL_loss_actual: 0.044503
#
# Accuracy of the mnist dataset: 0.955300
# Accuracy of the mnist_m dataset: 0.636040
#
#  epoch: 10, [iter: 461 / all 461], Total Loss: 0.141338, Network_loss:0.086522, CORAL_loss_actual: 0.054816
#
# Accuracy of the mnist dataset: 0.956500
# Accuracy of the mnist_m dataset: 0.653039
#
#  epoch: 11, [iter: 461 / all 461], Total Loss: 0.227956, Network_loss:0.174777, CORAL_loss_actual: 0.053179
#
# Accuracy of the mnist dataset: 0.964800
# Accuracy of the mnist_m dataset: 0.673036
#
#  epoch: 12, [iter: 461 / all 461], Total Loss: 0.160376, Network_loss:0.119123, CORAL_loss_actual: 0.041252
#
# Accuracy of the mnist dataset: 0.962400
# Accuracy of the mnist_m dataset: 0.679036
#
#  epoch: 13, [iter: 461 / all 461], Total Loss: 0.214785, Network_loss:0.172566, CORAL_loss_actual: 0.042219
#
# Accuracy of the mnist dataset: 0.963600
# Accuracy of the mnist_m dataset: 0.668370
#
#  epoch: 14, [iter: 461 / all 461], Total Loss: 0.135508, Network_loss:0.093265, CORAL_loss_actual: 0.042243
#
# Accuracy of the mnist dataset: 0.969800
# Accuracy of the mnist_m dataset: 0.689923
#
#  epoch: 15, [iter: 461 / all 461], Total Loss: 0.186676, Network_loss:0.136590, CORAL_loss_actual: 0.050085
#
# Accuracy of the mnist dataset: 0.970400
# Accuracy of the mnist_m dataset: 0.703366
#
#  epoch: 16, [iter: 461 / all 461], Total Loss: 0.187548, Network_loss:0.161519, CORAL_loss_actual: 0.026029
#
# Accuracy of the mnist dataset: 0.969800
# Accuracy of the mnist_m dataset: 0.695367
#
#  epoch: 17, [iter: 461 / all 461], Total Loss: 0.102018, Network_loss:0.073441, CORAL_loss_actual: 0.028577
#
# Accuracy of the mnist dataset: 0.971600
# Accuracy of the mnist_m dataset: 0.699367
#
#  epoch: 18, [iter: 461 / all 461], Total Loss: 0.166941, Network_loss:0.131482, CORAL_loss_actual: 0.035459
#
# Accuracy of the mnist dataset: 0.975600
# Accuracy of the mnist_m dataset: 0.707033
#
#  epoch: 19, [iter: 461 / all 461], Total Loss: 0.127238, Network_loss:0.095129, CORAL_loss_actual: 0.032108
#
# Accuracy of the mnist dataset: 0.977000
# Accuracy of the mnist_m dataset: 0.697145
#
#  epoch: 20, [iter: 461 / all 461], Total Loss: 0.106745, Network_loss:0.082382, CORAL_loss_actual: 0.024363
#
# Accuracy of the mnist dataset: 0.975900
# Accuracy of the mnist_m dataset: 0.707144
#
#  epoch: 21, [iter: 461 / all 461], Total Loss: 0.098607, Network_loss:0.071066, CORAL_loss_actual: 0.027540
#
# Accuracy of the mnist dataset: 0.980200
# Accuracy of the mnist_m dataset: 0.714809
#
#  epoch: 22, [iter: 461 / all 461], Total Loss: 0.133623, Network_loss:0.107079, CORAL_loss_actual: 0.026545
#
# Accuracy of the mnist dataset: 0.978800
# Accuracy of the mnist_m dataset: 0.720142
#
#  epoch: 23, [iter: 461 / all 461], Total Loss: 0.100263, Network_loss:0.081101, CORAL_loss_actual: 0.019162
#
# Accuracy of the mnist dataset: 0.979000
# Accuracy of the mnist_m dataset: 0.714587
#
#  epoch: 24, [iter: 461 / all 461], Total Loss: 0.108425, Network_loss:0.085050, CORAL_loss_actual: 0.023375
#
# Accuracy of the mnist dataset: 0.978000
# Accuracy of the mnist_m dataset: 0.733252
#
#  epoch: 25, [iter: 461 / all 461], Total Loss: 0.088188, Network_loss:0.069216, CORAL_loss_actual: 0.018972
#
# Accuracy of the mnist dataset: 0.976400
# Accuracy of the mnist_m dataset: 0.711254
#
#  epoch: 26, [iter: 461 / all 461], Total Loss: 0.085678, Network_loss:0.061415, CORAL_loss_actual: 0.024263
#
# Accuracy of the mnist dataset: 0.982600
# Accuracy of the mnist_m dataset: 0.722809
#
#  epoch: 27, [iter: 461 / all 461], Total Loss: 0.078922, Network_loss:0.059168, CORAL_loss_actual: 0.019754
#
# Accuracy of the mnist dataset: 0.980100
# Accuracy of the mnist_m dataset: 0.710366
#
#  epoch: 28, [iter: 461 / all 461], Total Loss: 0.090272, Network_loss:0.068603, CORAL_loss_actual: 0.021669
#
# Accuracy of the mnist dataset: 0.982200
# Accuracy of the mnist_m dataset: 0.732696
#
#  epoch: 29, [iter: 461 / all 461], Total Loss: 0.072781, Network_loss:0.046418, CORAL_loss_actual: 0.026363
#
# Accuracy of the mnist dataset: 0.982000
# Accuracy of the mnist_m dataset: 0.727586
#
#  epoch: 30, [iter: 461 / all 461], Total Loss: 0.050816, Network_loss:0.029735, CORAL_loss_actual: 0.021081
#
# Accuracy of the mnist dataset: 0.983100
# Accuracy of the mnist_m dataset: 0.724142
#
#  epoch: 31, [iter: 461 / all 461], Total Loss: 0.047716, Network_loss:0.030326, CORAL_loss_actual: 0.017390
#
# Accuracy of the mnist dataset: 0.984200
# Accuracy of the mnist_m dataset: 0.719253
#
#  epoch: 32, [iter: 461 / all 461], Total Loss: 0.087290, Network_loss:0.072192, CORAL_loss_actual: 0.015098
#
# Accuracy of the mnist dataset: 0.982300
# Accuracy of the mnist_m dataset: 0.731252
#
#  epoch: 33, [iter: 461 / all 461], Total Loss: 0.126372, Network_loss:0.106266, CORAL_loss_actual: 0.020106
#
# Accuracy of the mnist dataset: 0.985500
# Accuracy of the mnist_m dataset: 0.718476
#
#  epoch: 34, [iter: 461 / all 461], Total Loss: 0.119606, Network_loss:0.106890, CORAL_loss_actual: 0.012716
#
# Accuracy of the mnist dataset: 0.983200
# Accuracy of the mnist_m dataset: 0.721031
#
#  epoch: 35, [iter: 461 / all 461], Total Loss: 0.066007, Network_loss:0.048300, CORAL_loss_actual: 0.017707
#
# Accuracy of the mnist dataset: 0.982900
# Accuracy of the mnist_m dataset: 0.734918
#
#  epoch: 36, [iter: 461 / all 461], Total Loss: 0.073644, Network_loss:0.057855, CORAL_loss_actual: 0.015789
#
# Accuracy of the mnist dataset: 0.985000
# Accuracy of the mnist_m dataset: 0.724586
#
#  epoch: 37, [iter: 461 / all 461], Total Loss: 0.085072, Network_loss:0.067303, CORAL_loss_actual: 0.017768
#
# Accuracy of the mnist dataset: 0.983900
# Accuracy of the mnist_m dataset: 0.723142
#
#  epoch: 38, [iter: 461 / all 461], Total Loss: 0.110136, Network_loss:0.087295, CORAL_loss_actual: 0.022841
#
# Accuracy of the mnist dataset: 0.984500
# Accuracy of the mnist_m dataset: 0.741140
#
#  epoch: 39, [iter: 461 / all 461], Total Loss: 0.041363, Network_loss:0.027779, CORAL_loss_actual: 0.013584
#
# Accuracy of the mnist dataset: 0.986300
# Accuracy of the mnist_m dataset: 0.717920
#
#  epoch: 40, [iter: 461 / all 461], Total Loss: 0.040983, Network_loss:0.027353, CORAL_loss_actual: 0.013630
#
# Accuracy of the mnist dataset: 0.982800
# Accuracy of the mnist_m dataset: 0.739584
#
#  epoch: 41, [iter: 461 / all 461], Total Loss: 0.043143, Network_loss:0.030576, CORAL_loss_actual: 0.012568
#
# Accuracy of the mnist dataset: 0.983500
# Accuracy of the mnist_m dataset: 0.737474
#
#  epoch: 42, [iter: 461 / all 461], Total Loss: 0.037956, Network_loss:0.022719, CORAL_loss_actual: 0.015237
#
# Accuracy of the mnist dataset: 0.983800
# Accuracy of the mnist_m dataset: 0.729808
#
#  epoch: 43, [iter: 461 / all 461], Total Loss: 0.099994, Network_loss:0.087417, CORAL_loss_actual: 0.012577
#
# Accuracy of the mnist dataset: 0.986200
# Accuracy of the mnist_m dataset: 0.734585
#
#  epoch: 44, [iter: 461 / all 461], Total Loss: 0.061433, Network_loss:0.049920, CORAL_loss_actual: 0.011513
#
# Accuracy of the mnist dataset: 0.985600
# Accuracy of the mnist_m dataset: 0.739807
#
#  epoch: 45, [iter: 461 / all 461], Total Loss: 0.067498, Network_loss:0.051338, CORAL_loss_actual: 0.016160
#
# Accuracy of the mnist dataset: 0.986700
# Accuracy of the mnist_m dataset: 0.740140
#
#  epoch: 46, [iter: 461 / all 461], Total Loss: 0.058562, Network_loss:0.044457, CORAL_loss_actual: 0.014104
#
# Accuracy of the mnist dataset: 0.987300
# Accuracy of the mnist_m dataset: 0.735029
#
#  epoch: 47, [iter: 461 / all 461], Total Loss: 0.125519, Network_loss:0.115217, CORAL_loss_actual: 0.010301
#
# Accuracy of the mnist dataset: 0.985300
# Accuracy of the mnist_m dataset: 0.740029
#
#  epoch: 48, [iter: 461 / all 461], Total Loss: 0.030065, Network_loss:0.017292, CORAL_loss_actual: 0.012773
#
# Accuracy of the mnist dataset: 0.985600
# Accuracy of the mnist_m dataset: 0.746362
#
#  epoch: 49, [iter: 461 / all 461], Total Loss: 0.036575, Network_loss:0.021889, CORAL_loss_actual: 0.014686
#
# Accuracy of the mnist dataset: 0.985200
# Accuracy of the mnist_m dataset: 0.732919
#
#  epoch: 50, [iter: 461 / all 461], Total Loss: 0.034727, Network_loss:0.022268, CORAL_loss_actual: 0.012459
#
# Accuracy of the mnist dataset: 0.985800
# Accuracy of the mnist_m dataset: 0.729363
#
#  epoch: 51, [iter: 461 / all 461], Total Loss: 0.050549, Network_loss:0.039865, CORAL_loss_actual: 0.010684
#
# Accuracy of the mnist dataset: 0.986700
# Accuracy of the mnist_m dataset: 0.725031
#
#  epoch: 52, [iter: 461 / all 461], Total Loss: 0.034820, Network_loss:0.022589, CORAL_loss_actual: 0.012231
#
# Accuracy of the mnist dataset: 0.987500
# Accuracy of the mnist_m dataset: 0.730474
#
#  epoch: 53, [iter: 461 / all 461], Total Loss: 0.058625, Network_loss:0.045380, CORAL_loss_actual: 0.013245
#
# Accuracy of the mnist dataset: 0.986300
# Accuracy of the mnist_m dataset: 0.728364
#
#  epoch: 54, [iter: 461 / all 461], Total Loss: 0.072199, Network_loss:0.060754, CORAL_loss_actual: 0.011445
#
# Accuracy of the mnist dataset: 0.986200
# Accuracy of the mnist_m dataset: 0.748361
#
#  epoch: 55, [iter: 461 / all 461], Total Loss: 0.029336, Network_loss:0.020616, CORAL_loss_actual: 0.008720
#
# Accuracy of the mnist dataset: 0.985800
# Accuracy of the mnist_m dataset: 0.725808
#
#  epoch: 56, [iter: 461 / all 461], Total Loss: 0.027438, Network_loss:0.015201, CORAL_loss_actual: 0.012237
#
# Accuracy of the mnist dataset: 0.988300
# Accuracy of the mnist_m dataset: 0.730919
#
#  epoch: 57, [iter: 461 / all 461], Total Loss: 0.070563, Network_loss:0.058858, CORAL_loss_actual: 0.011705
#
# Accuracy of the mnist dataset: 0.987300
# Accuracy of the mnist_m dataset: 0.732807
#
#  epoch: 58, [iter: 461 / all 461], Total Loss: 0.056445, Network_loss:0.044227, CORAL_loss_actual: 0.012218
#
# Accuracy of the mnist dataset: 0.985900
# Accuracy of the mnist_m dataset: 0.733030
#
#  epoch: 59, [iter: 461 / all 461], Total Loss: 0.095831, Network_loss:0.085093, CORAL_loss_actual: 0.010739
#
# Accuracy of the mnist dataset: 0.987500
# Accuracy of the mnist_m dataset: 0.749250
#
#  epoch: 60, [iter: 461 / all 461], Total Loss: 0.030614, Network_loss:0.019121, CORAL_loss_actual: 0.011494
#
# Accuracy of the mnist dataset: 0.987100
# Accuracy of the mnist_m dataset: 0.741806
#
#  epoch: 61, [iter: 461 / all 461], Total Loss: 0.029270, Network_loss:0.016676, CORAL_loss_actual: 0.012594
#
# Accuracy of the mnist dataset: 0.988200
# Accuracy of the mnist_m dataset: 0.737918
#
#  epoch: 62, [iter: 461 / all 461], Total Loss: 0.047736, Network_loss:0.033703, CORAL_loss_actual: 0.014033
#
# Accuracy of the mnist dataset: 0.987000
# Accuracy of the mnist_m dataset: 0.742140
#
#  epoch: 63, [iter: 461 / all 461], Total Loss: 0.029859, Network_loss:0.021419, CORAL_loss_actual: 0.008441
#
# Accuracy of the mnist dataset: 0.987400
# Accuracy of the mnist_m dataset: 0.732807
#
#  epoch: 64, [iter: 461 / all 461], Total Loss: 0.034253, Network_loss:0.022825, CORAL_loss_actual: 0.011428
#
# Accuracy of the mnist dataset: 0.987500
# Accuracy of the mnist_m dataset: 0.734585
#
#  epoch: 65, [iter: 461 / all 461], Total Loss: 0.036697, Network_loss:0.026423, CORAL_loss_actual: 0.010273
#
# Accuracy of the mnist dataset: 0.986600
# Accuracy of the mnist_m dataset: 0.748250
#
#  epoch: 66, [iter: 461 / all 461], Total Loss: 0.040169, Network_loss:0.029544, CORAL_loss_actual: 0.010625
#
# Accuracy of the mnist dataset: 0.989000
# Accuracy of the mnist_m dataset: 0.746250
#
#  epoch: 67, [iter: 461 / all 461], Total Loss: 0.037887, Network_loss:0.025160, CORAL_loss_actual: 0.012727
#
# Accuracy of the mnist dataset: 0.985000
# Accuracy of the mnist_m dataset: 0.733585
#
#  epoch: 68, [iter: 461 / all 461], Total Loss: 0.038305, Network_loss:0.028959, CORAL_loss_actual: 0.009345
#
# Accuracy of the mnist dataset: 0.988700
# Accuracy of the mnist_m dataset: 0.739918
#
#  epoch: 69, [iter: 461 / all 461], Total Loss: 0.100464, Network_loss:0.089294, CORAL_loss_actual: 0.011170
#
# Accuracy of the mnist dataset: 0.987500
# Accuracy of the mnist_m dataset: 0.725364
#
#  epoch: 70, [iter: 461 / all 461], Total Loss: 0.058352, Network_loss:0.049404, CORAL_loss_actual: 0.008947
#
# Accuracy of the mnist dataset: 0.990300
# Accuracy of the mnist_m dataset: 0.742806
#
#  epoch: 71, [iter: 461 / all 461], Total Loss: 0.061727, Network_loss:0.052182, CORAL_loss_actual: 0.009545
#
# Accuracy of the mnist dataset: 0.987400
# Accuracy of the mnist_m dataset: 0.748250
#
#  epoch: 72, [iter: 461 / all 461], Total Loss: 0.080071, Network_loss:0.067101, CORAL_loss_actual: 0.012970
#
# Accuracy of the mnist dataset: 0.989400
# Accuracy of the mnist_m dataset: 0.742695
#
#  epoch: 73, [iter: 461 / all 461], Total Loss: 0.067832, Network_loss:0.057988, CORAL_loss_actual: 0.009844
#
# Accuracy of the mnist dataset: 0.988700
# Accuracy of the mnist_m dataset: 0.736140
#
#  epoch: 74, [iter: 461 / all 461], Total Loss: 0.026537, Network_loss:0.018072, CORAL_loss_actual: 0.008465
#
# Accuracy of the mnist dataset: 0.987700
# Accuracy of the mnist_m dataset: 0.742806
#
#  epoch: 75, [iter: 461 / all 461], Total Loss: 0.076458, Network_loss:0.067783, CORAL_loss_actual: 0.008675
#
# Accuracy of the mnist dataset: 0.990400
# Accuracy of the mnist_m dataset: 0.741251
#
#  epoch: 76, [iter: 461 / all 461], Total Loss: 0.014784, Network_loss:0.006405, CORAL_loss_actual: 0.008379
#
# Accuracy of the mnist dataset: 0.988900
# Accuracy of the mnist_m dataset: 0.744584
#
#  epoch: 77, [iter: 461 / all 461], Total Loss: 0.030060, Network_loss:0.020296, CORAL_loss_actual: 0.009764
#
# Accuracy of the mnist dataset: 0.989000
# Accuracy of the mnist_m dataset: 0.741918
#
#  epoch: 78, [iter: 461 / all 461], Total Loss: 0.019709, Network_loss:0.009461, CORAL_loss_actual: 0.010248
#
# Accuracy of the mnist dataset: 0.986700
# Accuracy of the mnist_m dataset: 0.744695
#
#  epoch: 79, [iter: 461 / all 461], Total Loss: 0.132990, Network_loss:0.121983, CORAL_loss_actual: 0.011006
#
# Accuracy of the mnist dataset: 0.989200
# Accuracy of the mnist_m dataset: 0.746917
#
# ============ Summary =============
#
# Accuracy of the mnist dataset: 0.987500
# Accuracy of the mnist_m dataset: 0.749250
# Corresponding model was save in ./out_ex3_cnn_da/mnist_mnistm_model_epoch_best.pth
# Save dict to ./out_ex3_cnn_da/losses.pkl

# %%
print('============ Summary ============= \n')
print('Accuracy of the %s dataset: %f' % ('mnist', max(losses['test']['acc_bw'])))
print('Accuracy of the %s dataset: %f' % ('mnist_m', max(losses['test']['acc_color'])))
print('Corresponding model was saved into ' + model_root + '/mnist_mnistm_model_epoch_best.pth')
# Out:
# ============ Summary =============
#
# Accuracy of the mnist dataset: 0.989700
# Accuracy of the mnist_m dataset: 0.770803
# Corresponding model was saved into ./out_ex3_cnn_da/mnist_mnistm_model_epoch_best.pth
